# %% [markdown]
# # Blogs recommendation model using w2v skipgram model

# %% [markdown]
# Reviewing the blogs analysis using tfidf metrics, we have some good results on the blogs embedding; however we can't use tfidf because it does not scale, the reason is that the shape of the matrix is dinamic and it's scale up depending on the quantity of unique words and blogs. That's not good because working with the tfidf matrix is not optimize. What we want is a fixed embedding dimension, and the only dinamic axis will be the blogs, so that our matrix just scale up along the blogs axis (the rows). That's why we are going to use glove with fixe dimension embedding of 300 to each word.

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import logging
import numpy as np
import pandas as pd

from tqdm import tqdm
from bs4 import BeautifulSoup
from utils import *

import matplotlib.pyplot as plt

warnings.filterwarnings("ignore")

tqdm.pandas(desc="Preprocess dataset")
# %matplotlib inline

# %%
logging.basicConfig(format="%(asctime)s : %(levelname)s : %(message)s", level=logging.INFO)
logger = logging.getLogger()

# %% [markdown]
# # Load dataset

# %%
blogs_df = pd.read_csv("data/blogs_data.csv")

# %%
blogs_df.head() # This data is already preprocess and normalize in English
# Out:
#      id                                              title  \
# 0  5173               Why Scalability Matters for Your App
# 1  5174  Is a Scrum Agile Development Process Right for...
# 2  5175  How to Make Your App Irresistible Through User...
# 3  5176  5 Product Manager MUSTS for Creating a Success...
# 4  5177  7 Key Questions to Ask Your Prospective App De...
#
#                                              content  \
# 0  Building an app is an extensive process. From ...
# 1  A Brief History of Scrum Agile Development: \n...
# 2  Guessing is a part of life—and it’s necessary....
# 3  Product management is a tough job. You must tr...
# 4  From the moment you decide to move forward wit...
#
#                                                 slug  \
# 0               why-scalability-matters-for-your-app
# 1  is-a-scrum-agile-development-process-right-for...
# 2  how-to-make-your-app-irresistible-through-user...
# 3  5-product-manager-musts-for-creating-a-success...
# 4  7-key-questions-to-ask-prospective-app-develop...
#
#                                                 data lang  \
# 0  Why Scalability Matters for Your App Building ...   en
# 1  Is a Scrum Agile Development Process Right for...   en
# 2  How to Make Your App Irresistible Through User...   en
# 3  5 Product Manager MUSTS for Creating a Success...   en
# 4  7 Key Questions to Ask Your Prospective App De...   en
#
#                                       normalize_data
# 0  Why Scalability Matters for Your App Building ...
# 1  Is a Scrum Agile Development Process Right for...
# 2  How to Make Your App Irresistible Through User...
# 3  5 Product Manager MUSTS for Creating a Success...
# 4  7 Key Questions to Ask Your Prospective App De...

# %%
print(blogs_df["normalize_data"][0])
# Out:
# Why Scalability Matters for Your App Building an app is an extensive process. From a fresh idea to a marketable product, the journey is filled with ups and downs. So, when you (hopefully) build that successful app, the last thing you want is for it to hit a dead end.
# However, that’s, unfortunately, the way it usually goes. You might think that accelerated growth is totally positive, as users are downloading your app at a record rate. But, an app that isn’t designed and developed to seamlessly handle this explosive growth will eventually end up being a failure.
# Consider this: is your app, as it stands today, able to scale up to exponential growth? If you have any doubts, you need to seriously consider this scalability issue.
#
# What is app scalability?
# Scalability is the ability of your app to handle a growing number of customers, clients and/or users. It also pertains to the ability of your current or future developer to maintain the app. Consider the possibility that your app isn’t currently scalable. If it’s not, be prepared to scramble to add necessary additional features without the flexible coding that keeps your app running smoothly.
# What are the benefits of a scalable app?
# You need to start your whole development process with scalability as a priority. After all, you want to assume rapid success when your app hits the market, and you certainly don’t want your hot product going belly up at the worst possible time. Here are some benefits:
# -Maintain a good user experience for your app over thousands of users
# Viral marketing can result in instant success—and a huge influx of traffic. But it’s usually a bit unpredictable. If your app is scalable, then you can accommodate this rapid growth with zero downtime—and without sacrificing user experience. When it comes to your marketing campaign, you can be confident about your app’s reliability.
# -Take advantage of holidays and other events (Olympics, Christmas, Black Friday, etc.) when app usage increases
# You can scale up and offer special deals for the holidays and other events—or, just be well-prepared for a quick increase in traffic. Scaling for a “Christmas” type moment can be frightening—you’re forced to confront the design decisions you made in the early stages of the app. If your app has hidden weaknesses, a massive new group of users will reveal them.
# -You won’t be tied to the original developer
# You won’t be held hostage by code so intricate that it can only be maintained by the developer who created it. You’ll be flexible, and able to hand off the project to other developers if necessary.
# -More potential for growth, a higher ROI, and more positive user feedback
# Wise app development allows for rapid growth. With comprehensive scalability testing, you can identify bugs and glitches before your users do…saving you hundreds of bad reviews.
# How to determine if your app is scalable
# Your app needs to be scalable from the start, way before it’s launched to the public. And the only way to truly know if the app can handle rapid scaling is by extensive testing. The reason scalability testing is necessary is that you need to know if your app can handle the enormous workload ahead while avoiding costly glitches and constant updates. The only way to truly know it’s ready is to consistently and comprehensively test it.
# Imagine taking a car to market without testing its durability, performance, brakes, and its ability to take tight turns. What if the safety features weren’t good enough to protect people in accidents? What if the engine doesn’t start on the showroom floor? Your brand would be tarnished.
# Applications are the same way. Even if your customers want all the benefits of using your app, they’ll be turned away by simple scalability and performance issues.
# Load testing is the process of putting demand on an app and measuring its response. No matter how many tests you run, load testing is really the only one way to determine if your software can handle the actual demands your thousands (or millions!) of end users will place on it.
# Load tests are specifically designed to assess response times and resource usage, while clearly pinpointing your app’s breaking point.
# Performance testing refers to testing done to analyze and improve your app’s performance. This sort of test is conducted to determine the status of your app’s active performance by carefully examining data mined from the testing process, and making your resource consumption optimal.
# Scalability testing refers to performance testing centered around understanding the scalability of an application. The goal is to determine the breaking point when the application stops scaling, and find the reason for it.
# Plan to scale from the beginning
# Before you start the development phase, you should be prepared to answer these important questions:
#
#
# How many users would you expect to use your new app within the year?
# Do you have a data collection plan?
#
# How long can all your customers fit on one server?
# What can you do when you have more customers or data than that?
#
# By assuring that your app is fully scalable from the beginning, you can absorb exponential growth with a minimum of downtime, all while optimizing user experience.
# Conclusion
# Scalability is crucial for your app’s success. When your app is scalable, it can accommodate growth, provide a good user experience for new users, and give you a better ROI. If you want to serve thousands or even millions with your app, you need to plan for it from the beginning.
# The ultimate purpose of scalability testing is to push the current app beyond its breaking point. Your team can then pinpoint that crucial moment, reverse engineer the problem, and make the app scalable and functional.
# Are you building a scalable application? Scaling an existing app? What challenges have you faced so far? Shoot us an email at mvp@koombea.com and let us know!
# Want more great tips to help you build a successful application? Subscribe below!
# Author: @keswanberg

# %% [markdown]
# # Preprocess data for training

# %%
regex = get_regex_expression()
regex
# Out:
# '(https?:\\/\\/.*[\\r\\n])|(\\#[^\\s]*)|(\\@[^\\s]*)|(author)|(\\S*@\\S+)|([^a-zA-Z0-9À-ÿ\\u00f1\\u00d1\\s])'

# %%
example = preprocess_data(blogs_df["normalize_data"][0], regex, 
                          removing_stops=True, lemmatize=True)
print(example)
# Out:
# ['scalability', 'matter', 'app', 'build', 'app', 'extensive', 'process', 'fresh', 'idea', 'marketable', 'product', 'journey', 'fill', 'up', 'down', 'hopefully', 'build', 'successful', 'app', 'thing', 'want', 'hit', 'dead', 'end', 'unfortunately', 'way', 'usually', 'go', 'think', 'accelerated', 'growth', 'totally', 'positive', 'user', 'download', 'app', 'record', 'rate', 'app', 'isn', 'design', 'develop', 'seamlessly', 'handle', 'explosive', 'growth', 'eventually', 'end', 'failure', 'consider', 'app', 'stand', 'today', 'able', 'scale', 'exponential', 'growth', 'doubt', 'need', 'seriously', 'consider', 'scalability', 'issue', 'app', 'scalability', 'scalability', 'ability', 'app', 'handle', 'grow', 'number', 'customer', 'client', 'user', 'pertain', 'ability', 'current', 'future', 'developer', 'maintain', 'app', 'consider', 'possibility', 'app', 'isn', 'currently', 'scalable', 'prepared', 'scramble', 'add', 'necessary', 'additional', 'feature', 'flexible', 'coding', 'keep', 'app', 'run', 'smoothly', 'benefit', 'scalable', 'app', 'need', 'start', 'development', 'process', 'scalability', 'priority', 'want', 'assume', 'rapid', 'success', 'app', 'hit', 'market', 'certainly', 'don', 'want', 'hot', 'product', 'go', 'belly', 'bad', 'possible', 'time', 'benefit', 'maintain', 'good', 'user', 'experience', 'app', 'thousand', 'user', 'viral', 'marketing', 'result', 'instant', 'success', 'huge', 'influx', 'traffic', 'usually', 'bit', 'unpredictable', 'app', 'scalable', 'accommodate', 'rapid', 'growth', 'downtime', 'sacrifice', 'user', 'experience', 'come', 'marketing', 'campaign', 'confident', 'app', 'reliability', 'advantage', 'holiday', 'event', 'olympics', 'christmas', 'black', 'friday', 'etc', 'app', 'usage', 'increase', 'scale', 'offer', 'special', 'deal', 'holiday', 'event', 'prepared', 'quick', 'increase', 'traffic', 'scale', 'christmas', 'type', 'moment', 'frightening', 'force', 'confront', 'design', 'decision', 'early', 'stage', 'app', 'app', 'hide', 'weakness', 'massive', 'new', 'group', 'user', 'reveal', 'win', 'tie', 'original', 'developer', 'win', 'hold', 'hostage', 'code', 'intricate', 'maintain', 'developer', 'create', 'will', 'flexible', 'able', 'hand', 'project', 'developer', 'necessary', 'potential', 'growth', 'high', 'roi', 'positive', 'user', 'feedback', 'wise', 'app', 'development', 'allow', 'rapid', 'growth', 'comprehensive', 'scalability', 'testing', 'identify', 'bug', 'glitch', 'user', 'save', 'hundred', 'bad', 'review', 'determine', 'app', 'scalable', 'app', 'need', 'scalable', 'start', 'way', 'launch', 'public', 'way', 'truly', 'know', 'app', 'handle', 'rapid', 'scaling', 'extensive', 'testing', 'reason', 'scalability', 'testing', 'necessary', 'need', 'know', 'app', 'handle', 'enormous', 'workload', 'ahead', 'avoid', 'costly', 'glitch', 'constant', 'update', 'way', 'truly', 'know', 'ready', 'consistently', 'comprehensively', 'test', 'imagine', 'take', 'car', 'market', 'test', 'durability', 'performance', 'brake', 'ability', 'tight', 'turn', 'safety', 'feature', 'weren', 'good', 'protect', 'people', 'accident', 'engine', 'doesn', 'start', 'showroom', 'floor', 'brand', 'tarnish', 'application', 'way', 'customer', 'want', 'benefit', 'app', 'will', 'turn', 'away', 'simple', 'scalability', 'performance', 'issue', 'load', 'testing', 'process', 'put', 'demand', 'app', 'measure', 'response', 'matter', 'test', 'run', 'load', 'testing', 'way', 'determine', 'software', 'handle', 'actual', 'demand', 'thousand', 'million', 'end', 'user', 'place', 'load', 'test', 'specifically', 'design', 'assess', 'response', 'time', 'resource', 'usage', 'clearly', 'pinpoint', 'app', 'breaking', 'point', 'performance', 'testing', 'refer', 'testing', 'analyze', 'improve', 'app', 'performance', 'sort', 'test', 'conduct', 'determine', 'status', 'app', 'active', 'performance', 'carefully', 'examine', 'datum', 'mine', 'testing', 'process', 'make', 'resource', 'consumption', 'optimal', 'scalability', 'testing', 'refer', 'performance', 'testing', 'cente ...

# %%
# Train data doing lemmatization and removing stopswords
train_data = [preprocess_data(normalize_data, regex, True, True) 
                for normalize_data in tqdm(blogs_df["normalize_data"].values)]
# Out:
# 100%|██████████| 458/458 [00:47<00:00,  9.62it/s]

# %%
print(train_data[0])
# Out:
# ['scalability', 'matter', 'app', 'build', 'app', 'extensive', 'process', 'fresh', 'idea', 'marketable', 'product', 'journey', 'fill', 'up', 'down', 'hopefully', 'build', 'successful', 'app', 'thing', 'want', 'hit', 'dead', 'end', 'unfortunately', 'way', 'usually', 'go', 'think', 'accelerated', 'growth', 'totally', 'positive', 'user', 'download', 'app', 'record', 'rate', 'app', 'isn', 'design', 'develop', 'seamlessly', 'handle', 'explosive', 'growth', 'eventually', 'end', 'failure', 'consider', 'app', 'stand', 'today', 'able', 'scale', 'exponential', 'growth', 'doubt', 'need', 'seriously', 'consider', 'scalability', 'issue', 'app', 'scalability', 'scalability', 'ability', 'app', 'handle', 'grow', 'number', 'customer', 'client', 'user', 'pertain', 'ability', 'current', 'future', 'developer', 'maintain', 'app', 'consider', 'possibility', 'app', 'isn', 'currently', 'scalable', 'prepared', 'scramble', 'add', 'necessary', 'additional', 'feature', 'flexible', 'coding', 'keep', 'app', 'run', 'smoothly', 'benefit', 'scalable', 'app', 'need', 'start', 'development', 'process', 'scalability', 'priority', 'want', 'assume', 'rapid', 'success', 'app', 'hit', 'market', 'certainly', 'don', 'want', 'hot', 'product', 'go', 'belly', 'bad', 'possible', 'time', 'benefit', 'maintain', 'good', 'user', 'experience', 'app', 'thousand', 'user', 'viral', 'marketing', 'result', 'instant', 'success', 'huge', 'influx', 'traffic', 'usually', 'bit', 'unpredictable', 'app', 'scalable', 'accommodate', 'rapid', 'growth', 'downtime', 'sacrifice', 'user', 'experience', 'come', 'marketing', 'campaign', 'confident', 'app', 'reliability', 'advantage', 'holiday', 'event', 'olympics', 'christmas', 'black', 'friday', 'etc', 'app', 'usage', 'increase', 'scale', 'offer', 'special', 'deal', 'holiday', 'event', 'prepared', 'quick', 'increase', 'traffic', 'scale', 'christmas', 'type', 'moment', 'frightening', 'force', 'confront', 'design', 'decision', 'early', 'stage', 'app', 'app', 'hide', 'weakness', 'massive', 'new', 'group', 'user', 'reveal', 'win', 'tie', 'original', 'developer', 'win', 'hold', 'hostage', 'code', 'intricate', 'maintain', 'developer', 'create', 'will', 'flexible', 'able', 'hand', 'project', 'developer', 'necessary', 'potential', 'growth', 'high', 'roi', 'positive', 'user', 'feedback', 'wise', 'app', 'development', 'allow', 'rapid', 'growth', 'comprehensive', 'scalability', 'testing', 'identify', 'bug', 'glitch', 'user', 'save', 'hundred', 'bad', 'review', 'determine', 'app', 'scalable', 'app', 'need', 'scalable', 'start', 'way', 'launch', 'public', 'way', 'truly', 'know', 'app', 'handle', 'rapid', 'scaling', 'extensive', 'testing', 'reason', 'scalability', 'testing', 'necessary', 'need', 'know', 'app', 'handle', 'enormous', 'workload', 'ahead', 'avoid', 'costly', 'glitch', 'constant', 'update', 'way', 'truly', 'know', 'ready', 'consistently', 'comprehensively', 'test', 'imagine', 'take', 'car', 'market', 'test', 'durability', 'performance', 'brake', 'ability', 'tight', 'turn', 'safety', 'feature', 'weren', 'good', 'protect', 'people', 'accident', 'engine', 'doesn', 'start', 'showroom', 'floor', 'brand', 'tarnish', 'application', 'way', 'customer', 'want', 'benefit', 'app', 'will', 'turn', 'away', 'simple', 'scalability', 'performance', 'issue', 'load', 'testing', 'process', 'put', 'demand', 'app', 'measure', 'response', 'matter', 'test', 'run', 'load', 'testing', 'way', 'determine', 'software', 'handle', 'actual', 'demand', 'thousand', 'million', 'end', 'user', 'place', 'load', 'test', 'specifically', 'design', 'assess', 'response', 'time', 'resource', 'usage', 'clearly', 'pinpoint', 'app', 'breaking', 'point', 'performance', 'testing', 'refer', 'testing', 'analyze', 'improve', 'app', 'performance', 'sort', 'test', 'conduct', 'determine', 'status', 'app', 'active', 'performance', 'carefully', 'examine', 'datum', 'mine', 'testing', 'process', 'make', 'resource', 'consumption', 'optimal', 'scalability', 'testing', 'refer', 'performance', 'testing', 'cente ...

# %% [markdown]
# # Create a model with gensim

# %% [markdown]
# ## Gensim api Important hyperparameters
# ```
# sentences : iterable of iterables, optional
#             The `sentences` iterable can be simply a list of lists of tokens.
#
# size : int, optional
#     Dimensionality of the word vectors.
#
# window : int, optional
#     Maximum distance between the current and predicted word within a sentence.
#
# min_count : int, optional
#     Ignores all words with total frequency lower than this.
#
# workers : int, optional
#     Use these many worker threads to train the model (=faster training with multicore machines).
#
# sg : {0, 1}, optional
#     Training algorithm: 1 for skip-gram; otherwise CBOW.
#
# hs : {0, 1}, optional
#     If 1, hierarchical softmax will be used for model training.
#     If 0, and `negative` is non-zero, negative sampling will be used.
#
# negative : int, optional
#     If > 0, negative sampling will be used, the int for negative specifies how many "noise words"
#     should be drawn (usually between 5-20).
#     If set to 0, no negative sampling is used.
#
# ns_exponent : float, optional
#         The exponent used to shape the negative sampling distribution. A value of 1.0 samples exactly in               proportion to the frequencies, 0.0 samples all words equally, while a negative value samples
#         low-frequency words more than high-frequency words. The popular default value of 0.75 was chosen by
#         the original Word2Vec paper.
#
# cbow_mean : {0, 1}, optional
#     If 0, use the sum of the context word vectors. If 1, use the mean, only applies when cbow is used.
#
# alpha : float, optional
#     The initial learning rate.
#
# min_alpha : float, optional
#     Learning rate will linearly drop to `min_alpha` as training progresses.
#
# max_vocab_size : int, optional
#     Limits the RAM during vocabulary building; if there are more unique
#     words than this, then prune the infrequent ones. Every 10 million word types need about 1GB of RAM.
#     Set to `None` for no limit.
#
# max_final_vocab : int, optional
#     Limits the vocab to a target vocab size by automatically picking a matching min_count. If the specified
#     min_count is more than the calculated min_count, the specified min_count will be used.
#     Set to `None` if not required.
#
# sample : float, optional
#     The threshold for configuring which higher-frequency words are randomly downsampled,
#     useful range is (0, 1e-5).
#
# iter : int, optional
#     Number of iterations (epochs) over the corpus.
#
# trim_rule : function, optional
#     Vocabulary trimming rule, specifies whether certain words should remain in the vocabulary,
#     be trimmed away, or handled using the default (discard if word count < min_count).
#     Can be None (min_count will be used, look to :func:`~gensim.utils.keep_vocab_item`),
#     or a callable that accepts parameters (word, count, min_count) and returns either
#     :attr:`gensim.utils.RULE_DISCARD`, :attr:`gensim.utils.RULE_KEEP` or :attr:`gensim.utils.RULE_DEFAULT`.
#     The rule, if given, is only used to prune vocabulary during build_vocab() and is not stored as part of the
#     model.
#
#     The input parameters are of the following types:
#         * `word` (str) - the word we are examining
#         * `count` (int) - the word's frequency count in the corpus
#         * `min_count` (int) - the minimum count threshold.
#
# sorted_vocab : {0, 1}, optional
#     If 1, sort the vocabulary by descending frequency before assigning word indexes.
#     See :meth:`~gensim.models.word2vec.Word2VecVocab.sort_vocab()`.
#
# batch_words : int, optional
#     Target size (in words) for batches of examples passed to worker threads (and
#     thus cython routines).(Larger batches will be passed if individual
#     texts are longer than 10000 words, but the standard cython code truncates to that maximum.)
# ```
# To see the best choose of hyperparameter this paper:
#
# https://arxiv.org/pdf/1804.04212.pdf

# %%
from gensim.models import Word2Vec
import multiprocessing
number_cpus = multiprocessing.cpu_count()
# Out:
# 2020-06-08 19:55:31,553 : INFO : 'pattern' package not found; tag filters are not available for English

# %% [markdown]
# ## Define hyperparameters

# %%
parameters = {"min_count":0, "size":300, "sg":1, "window":5, "iter":110,
                   "sample": 1e-5, "hs": 0, "negative": 15, "ns_exponent": -0.5,
                   "workers": number_cpus}

# %%
sg_model = Word2Vec(**parameters)

# %% [markdown]
# ## Build vocab

# %%
# Build vocab
sg_model.build_vocab(train_data, progress_per=100000)
# Out:
# 2020-06-08 19:55:31,622 : INFO : collecting all words and their counts
# 2020-06-08 19:55:31,622 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2020-06-08 19:55:31,650 : INFO : collected 10286 word types from a corpus of 224885 raw words and 458 sentences
# 2020-06-08 19:55:31,651 : INFO : Loading a fresh vocabulary
# 2020-06-08 19:55:31,668 : INFO : effective_min_count=0 retains 10286 unique words (100% of original 10286, drops 0)
# 2020-06-08 19:55:31,668 : INFO : effective_min_count=0 leaves 224885 word corpus (100% of original 224885, drops 0)
# 2020-06-08 19:55:31,702 : INFO : deleting the raw counts dictionary of 10286 items
# 2020-06-08 19:55:31,703 : INFO : sample=1e-05 downsamples 3308 most-common words
# 2020-06-08 19:55:31,703 : INFO : downsampling leaves estimated 51171 word corpus (22.8% of prior 224885)
# 2020-06-08 19:55:31,740 : INFO : estimated required memory for 10286 words and 300 dimensions: 29829400 bytes
# 2020-06-08 19:55:31,741 : INFO : resetting layer weights

# %% [markdown]
# ## Load pretrained vectors
#
# Run to compare with differen pretrained vectors

# %%
# sg_model.intersect_word2vec_format("model/word2vec-google-news-300.gz", binary=True)

# %% [markdown]
# ## Train skip-gram model

# %%
sg_model.train(train_data, total_examples=sg_model.corpus_count, 
                  epochs=sg_model.epochs)
# Out:
# 2020-06-08 19:55:33,430 : INFO : training model with 8 workers on 10286 vocabulary and 300 features, using sg=1 hs=0 sample=1e-05 negative=15 window=5
# 2020-06-08 19:55:33,794 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-08 19:55:33,857 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-08 19:55:33,868 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-08 19:55:33,870 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-08 19:55:33,874 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-08 19:55:33,876 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-08 19:55:33,879 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-08 19:55:33,883 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-08 19:55:33,885 : INFO : EPOCH - 1 : training on 224885 raw words (51188 effective words) took 0.4s, 114124 effective words/s
# 2020-06-08 19:55:34,249 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-08 19:55:34,297 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-08 19:55:34,302 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-08 19:55:34,317 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-08 19:55:34,325 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-08 19:55:34,330 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-08 19:55:34,331 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-08 19:55:34,341 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-08 19:55:34,342 : INFO : EPOCH - 2 : training on 224885 raw words (51314 effective words) took 0.5s, 113762 effective words/s
# 2020-06-08 19:55:34,705 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-08 19:55:34,736 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-08 19:55:34,752 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-08 19:55:34,773 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-08 19:55:34,775 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-08 19:55:34,776 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-08 19:55:34,780 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-08 19:55:34,787 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-08 19:55:34,788 : INFO : EPOCH - 3 : training on 224885 raw words (51020 effective words) took 0.4s, 115865 effective words/s
# 2020-06-08 19:55:35,147 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-08 19:55:35,181 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-08 19:55:35,206 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-08 19:55:35,208 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-08 19:55:35,210 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-08 19:55:35,219 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-08 19:55:35,220 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-08 19:55:35,222 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-08 19:55:35,222 : INFO : EPOCH - 4 : training on 224885 raw words (51336 effective words) took 0.4s, 119277 effective words/s
# 2020-06-08 19:55:35,586 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-08 19:55:35,604 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-08 19:55:35,623 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-08 19:55:35,634 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-08 19:55:35,640 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-08 19:55:35,641 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-08 19:55:35,642 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-08 19:55:35,649 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-08 19:55:35,650 : INFO : EPOCH - 5 : training on 224885 raw words (51109 effective words) took 0.4s, 120921 effective words/s
# 2020-06-08 19:55:35,995 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-08 19:55:36,050 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-08 19:55:36,059 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-08 19:55:36,060 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-08 19:55:36,067 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-08 19:55:36,071 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-08 19:55:36,073 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-08 19:55:36,074 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-08 19:55:36,074 : INFO : EPOCH - 6 : training on 224885 raw words (51087 effective words) took 0.4s, 121158 effective words/s
# 2020-06-08 19:55:36,423 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-08 19:55:36,453 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-08 19:55:36,473 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-08 19:55:36,481 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-08 19:55:36,488 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-08 19:55:36,496 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-08 19:55:36,502 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-08 19:55:36,506 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-08 19:55:36,507 : INFO : EPOCH - 7 : training on 224885 raw words (50942 effective words) took 0.4s, 118430 effective words/s
# 2020-06-08 19:55:36,847 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-08 19:55:36,895 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-08 19:55:36,913 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-08 19:55:36,920 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-08 19:55:36,921 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-08 19:55:36,922 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-08 19:55:36,930 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-08 19:55:36,931 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-08 19:55:36,931 : INFO : EPOCH - 8 : training on 224885 raw words (51232 effective words) took 0.4s, 121802 effective words/s
# 2020-06-08 19:55:37,288 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-08 19:55:37,346 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-08 19:55:37,349 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-08 19:55:37,353 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-08 19:55:37,354 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-08 19:55:37,355 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-08 19:55:37,360 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-08 19:55:37,365 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-08 19:55:37,365 : INFO : EPOCH - 9 : training on 224885 raw words (51188 effective words) took 0.4s, 119018 effective words/s
# 2020-06-08 19:55:37,710 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-08 19:55:37,747 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-08 19:55:37,762 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-08 19:55:37,769 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-08 19:55:37,770 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-08 19:55:37,772 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-08 19:55:37,783 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-08 19:55:37,784 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-08 19:55:37,784 : INFO : EPOCH - 10 : training on 224885 raw words (51237 effective words) took 0.4s, 123274 effective words/s
# 2020-06-08 19:55:38,138 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-08 19:55:38,177 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-08 19:55:38,194 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-08 19:55:38,199 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-08 19:55:38,207 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-08 19:55:38,207 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-08 19:55:38,216 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-08 19:55:38,217 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-08 19:55
: INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-08 19:56:15,369 : INFO : EPOCH - 101 : training on 224885 raw words (51107 effective words) took 0.4s, 136995 effective words/s
# 2020-06-08 19:56:15,689 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-08 19:56:15,711 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-08 19:56:15,732 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-08 19:56:15,734 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-08 19:56:15,741 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-08 19:56:15,748 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-08 19:56:15,751 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-08 19:56:15,753 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-08 19:56:15,754 : INFO : EPOCH - 102 : training on 224885 raw words (51178 effective words) took 0.4s, 135743 effective words/s
# 2020-06-08 19:56:16,066 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-08 19:56:16,089 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-08 19:56:16,111 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-08 19:56:16,114 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-08 19:56:16,116 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-08 19:56:16,119 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-08 19:56:16,124 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-08 19:56:16,136 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-08 19:56:16,137 : INFO : EPOCH - 103 : training on 224885 raw words (51222 effective words) took 0.4s, 134877 effective words/s
# 2020-06-08 19:56:16,447 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-08 19:56:16,474 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-08 19:56:16,491 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-08 19:56:16,499 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-08 19:56:16,505 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-08 19:56:16,512 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-08 19:56:16,519 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-08 19:56:16,519 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-08 19:56:16,520 : INFO : EPOCH - 104 : training on 224885 raw words (51116 effective words) took 0.4s, 134605 effective words/s
# 2020-06-08 19:56:16,825 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-08 19:56:16,863 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-08 19:56:16,888 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-08 19:56:16,889 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-08 19:56:16,892 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-08 19:56:16,893 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-08 19:56:16,894 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-08 19:56:16,895 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-08 19:56:16,896 : INFO : EPOCH - 105 : training on 224885 raw words (51159 effective words) took 0.4s, 137394 effective words/s
# 2020-06-08 19:56:17,212 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-08 19:56:17,249 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-08 19:56:17,262 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-08 19:56:17,266 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-08 19:56:17,267 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-08 19:56:17,269 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-08 19:56:17,276 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-08 19:56:17,290 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-08 19:56:17,291 : INFO : EPOCH - 106 : training on 224885 raw words (51166 effective words) took 0.4s, 131189 effective words/s
# 2020-06-08 19:56:17,673 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-08 19:56:17,694 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-08 19:56:17,702 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-08 19:56:17,706 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-08 19:56:17,707 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-08 19:56:17,712 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-08 19:56:17,740 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-08 19:56:17,743 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-08 19:56:17,744 : INFO : EPOCH - 107 : training on 224885 raw words (50904 effective words) took 0.4s, 116971 effective words/s
# 2020-06-08 19:56:18,082 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-08 19:56:18,099 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-08 19:56:18,104 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-08 19:56:18,106 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-08 19:56:18,121 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-08 19:56:18,125 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-08 19:56:18,143 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-08 19:56:18,145 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-08 19:56:18,145 : INFO : EPOCH - 108 : training on 224885 raw words (51174 effective words) took 0.4s, 128465 effective words/s
# 2020-06-08 19:56:18,466 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-08 19:56:18,484 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-08 19:56:18,505 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-08 19:56:18,515 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-08 19:56:18,516 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-08 19:56:18,525 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-08 19:56:18,527 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-08 19:56:18,536 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-08 19:56:18,537 : INFO : EPOCH - 109 : training on 224885 raw words (51078 effective words) took 0.4s, 131522 effective words/s
# 2020-06-08 19:56:18,841 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-08 19:56:18,886 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-08 19:56:18,893 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-08 19:56:18,895 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-08 19:56:18,901 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-08 19:56:18,908 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-08 19:56:18,912 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-08 19:56:18,919 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-08 19:56:18,919 : INFO : EPOCH - 110 : training on 224885 raw words (51396 effective words) took 0.4s, 135469 effective words/s
# 2020-06-08 19:56:18,920 : INFO : training on a 24737350 raw words (5626864 effective words) took 45.5s, 123699 effective words/s
# (5626864, 24737350)

# %% [markdown]
# ## Test word similarity

# %%
sg_model.wv.most_similar("ai")
# Out:
# 2020-06-08 19:56:18,943 : INFO : precomputing L2-norms of word weight vectors
# [('intelligence', 0.724933385848999),
#  ('artificial', 0.7191296219825745),
#  ('organizations', 0.655931830406189),
#  ('indistinctly', 0.6269644498825073),
#  ('ml', 0.6250787973403931),
#  ('1960', 0.6126772165298462),
#  ('rational', 0.6074848175048828),
#  ('rumor', 0.605669379234314),
#  ('50s', 0.6000031232833862),
#  ('40', 0.5982970595359802)]

# %%
sg_model.wv.most_similar("devops")
# Out:
# [('digitalocean', 0.7404625415802002),
#  ('linode', 0.7377272844314575),
#  ('staging', 0.7347713708877563),
#  ('handoff', 0.7145954370498657),
#  ('ebb', 0.7063966989517212),
#  ('philosophy', 0.6975865364074707),
#  ('refinement', 0.6940504312515259),
#  ('qc', 0.6876996755599976),
#  ('ethos', 0.6861399412155151),
#  ('concert', 0.6860008239746094)]

# %%
sg_model.wv.most_similar("python")
# Out:
# [('django', 0.9067569971084595),
#  ('broader', 0.8693179488182068),
#  ('lifelong', 0.837437093257904),
#  ('academia', 0.8366538882255554),
#  ('raspberry', 0.8228967785835266),
#  ('compiled', 0.817995548248291),
#  ('languages', 0.8179847598075867),
#  ('pi', 0.7913285493850708),
#  ('coincidence', 0.7679840922355652),
#  ('jeopardize', 0.7217299938201904)]

# %%
sg_model.wv.most_similar("java")
# Out:
# [('ee', 0.9084498286247253),
#  ('fx', 0.8969416618347168),
#  ('appropriateness', 0.8847925662994385),
#  ('runtime', 0.8776237368583679),
#  ('syntax', 0.8621473908424377),
#  ('bytecode', 0.861548662185669),
#  ('jms', 0.8565928339958191),
#  ('compiler', 0.8559286594390869),
#  ('tiobe', 0.8398691415786743),
#  ('orderly', 0.8318889141082764)]

# %% [markdown]
# ## Visualize words embedding

# %% [markdown]
# ### Truncated svd to reduce dimension down to 50

# %%
matrix = sg_model[sg_model.wv.vocab]

# %%
from sklearn.decomposition import TruncatedSVD
truncated_svd = TruncatedSVD(n_components=50)

# %%
matrix_truncated = truncated_svd.fit_transform(matrix)

# %% [markdown]
# ### tsne manifold to reduce dimension down to 2

# %%
from sklearn.manifold import TSNE

# %%
matrix_ = TSNE(perplexity=50).fit_transform(matrix_truncated)

# %%
vocab = np.array(list(sg_model.wv.vocab.keys()))

# %%
vocab[100:120]
# Out:
# array(['traffic', 'bit', 'unpredictable', 'accommodate', 'downtime',
#        'sacrifice', 'come', 'campaign', 'confident', 'reliability',
#        'advantage', 'holiday', 'event', 'olympics', 'christmas', 'black',
#        'friday', 'etc', 'usage', 'increase'], dtype='<U21')

# %% [markdown]
# ### Visualize words

# %%
# %matplotlib inline
visualize_words_embedding(matrix_, vocab, total=300, width=15, height=10)

# %% [markdown]
# # Blogs embedding

# %%
from fse.models import SIF, Average
from fse import IndexedList
import pickle

# %%
fse_data = IndexedList(train_data) # Tranform to fse format

# %%
fse_model = SIF(sg_model, workers=number_cpus, lang_freq='en') #own model
# Out:
# 2020-06-08 19:57:23,681 : INFO : no frequency mode: using wordfreq for estimation of frequency for language: en

# %%
fse_model.train(fse_data)
# Out:
# 2020-06-08 19:57:23,794 : INFO : scanning all indexed sentences and their word counts
# 2020-06-08 19:57:23,795 : INFO : finished scanning 458 sentences with an average length of 491 and 224885 total words
# 2020-06-08 19:57:23,798 : INFO : estimated memory for 458 sentences with 300 dimensions and 10286 vocabulary: 12 MB (0 GB)
# 2020-06-08 19:57:23,799 : INFO : initializing sentence vectors for 458 sentences
# 2020-06-08 19:57:23,802 : INFO : pre-computing SIF weights for 10286 words
# 2020-06-08 19:57:23,807 : INFO : begin training
# 2020-06-08 19:57:23,860 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-08 19:57:23,861 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-08 19:57:23,861 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-08 19:57:23,862 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-08 19:57:23,862 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-08 19:57:23,862 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-08 19:57:23,863 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-08 19:57:23,864 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-08 19:57:23,868 : INFO : computing 1 principal components took 0s
# 2020-06-08 19:57:23,868 : INFO : removing 1 principal components took 0s
# 2020-06-08 19:57:23,869 : INFO : training on 458 effective sentences with 224885 effective words took 0s with 8036 sentences/s
# (458, 224885)

# %%
blog_matrix = fse_model.sv.vectors
blog_matrix.shape
# Out:
# (458, 300)

# %%
TFIDF_MATRIX = pickle.load(open("model/tfidf_unigrams.pickle", "rb"))
vocab_ = pickle.load(open("model/vocab_unigrams.pickle", "rb"))

# %% [markdown]
# ## Visualize blogs embeddings

# %% [markdown]
# ### Trucated svd to reduce simension down to 50

# %%
blog_matrix_truncated = TruncatedSVD(n_components=50).fit_transform(blog_matrix)

# %% [markdown]
# ### Tsne manifold to reduce dimension down to 2

# %%
blog_matrix_tsne = TSNE(n_components=2).fit_transform(blog_matrix_truncated)

# %% [markdown]
# ### Visualize words

# %%
from sklearn.cluster import KMeans

# %%
clusters = KMeans(n_clusters=25).fit_predict(blog_matrix_tsne)

# %%
# %matplotlib inline
plots_blogs_embedding(TFIDF_MATRIX, blog_matrix_tsne, vocab_, clusters, width=15, height=10)

# %% [markdown]
# We can see some cluster for example blogs with ai, and machine learning topic are together, blogs about vr, ar are together, blogs about gamification too

# %% [markdown]
# # Similarity Query

# %%
from gensim.summarization import summarize

# %% [markdown]
# ## Pick a blog and summarize using gensim

# %%
print(blogs_df.title[455].upper())
print(summarize(blogs_df.normalize_data[455]))
# Out:
# 2020-06-08 19:57:26,969 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2020-06-08 19:57:26,970 : INFO : built Dictionary(329 unique tokens: ['bad', 'covid', 'depress', 'econom', 'enter']...) from 82 documents (total 573 corpus positions)
# 2020-06-08 19:57:26,972 : INFO : Building graph
# 2020-06-08 19:57:26,973 : INFO : Filling graph
# 2020-06-08 19:57:26,981 : INFO : Removing unreachable nodes of graph
# 2020-06-08 19:57:26,983 : INFO : Pagerank graph
# 2020-06-08 19:57:26,995 : INFO : Sorting pagerank scores
# FINTECH TRENDS 2020: THE GOOD, THE BAD, AND THE UGLY
# FinTech Trends 2020: The Good, the Bad, and the Ugly Due to the Covid-19 pandemic, the world is entering an economic turmoil not seen since the Great Depression.
# Governments all over the world are implementing generous aid programs to help companies and people, but uncertainty prevails.
# FinTech, a sector that was performing great before Covid-19, is at the crossroads between surviving the crisis and a universe of opportunities.
# In this post we analyze some of the most important FinTech trends that investors and managers should keep on their radar if they wish to stay afloat and come out of the crisis stronger.
# Although some FinTech companies are struggling due to the economy’s overall impact, it is safe to say that the majority continue to operate at levels of performance equal to or above before the pandemic.
# Some FinTech real estate and insurance companies seem to be having a hard time, although this seems more of a temporary issue rather than a new normal.
# Consumption in many non-essential industries has seen a major fall, affecting the circulation of money in the economy.
# With less money to buy certain goods and services, FinTech companies need to focus on delivering products that fall within households’ priorities.
# Countries and central banks are reducing their interest rates, affecting FinTech companies in one way or another.
# FinTech companies are not immune to shifts on the way we work as a result of the pandemic.
# FinTech has a great opportunity both in eCommerce customers as well as companies that need to grow to satisfy the increase in online demand.
# There seems to be a whole new market of companies that are seeking FinTech apps to help them adapt their businesses to the digital world.
# At Koombea we are excited to see what new FinTech apps will be developed in order to confront the crisis.
# One of the strongest trends we expect to see throughout 2020 and in the coming years is an increase in FinTech app development.
# Koombea has over 12 years of experience helping FinTech companies bring ideas to life.
# Contact us and make sure that your company stays afloat throughout this crisis.

# %% [markdown]
# the blogs is about Fintech trends in 2020 and the impact dur to the covid-19 over fintech world, let's search for some similar blogs

# %%
values = fse_model.sv.most_similar(455, topn=3)
values_ = [val[0] for val in values]
values
# Out:
# 2020-06-08 19:57:27,027 : INFO : precomputing L2-norms of sentence vectors
# [(447, 0.6634736061096191),
#  (395, 0.6402407288551331),
#  (450, 0.6398809552192688)]

# %%
print(blogs_df.title[values_[0]].upper())
print(summarize(blogs_df.normalize_data[values_[0]]))
print("\n")
print(blogs_df.title[values_[1]].upper())
print(summarize(blogs_df.normalize_data[values_[1]]))
print("\n")
print(blogs_df.title[values_[2]].upper())
print(summarize(blogs_df.normalize_data[values_[2]]))
# Out:
# 2020-06-08 19:57:27,088 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2020-06-08 19:57:27,090 : INFO : built Dictionary(321 unique tokens: ['financi', 'fintech', 'histor', 'institut', 'matter']...) from 85 documents (total 682 corpus positions)
# 2020-06-08 19:57:27,092 : INFO : Building graph
# 2020-06-08 19:57:27,092 : INFO : Filling graph
# 2020-06-08 19:57:27,114 : INFO : Removing unreachable nodes of graph
# 2020-06-08 19:57:27,115 : INFO : Pagerank graph
# 2020-06-08 19:57:27,128 : INFO : Sorting pagerank scores
# 2020-06-08 19:57:27,139 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2020-06-08 19:57:27,141 : INFO : built Dictionary(246 unique tokens: ['ago', 'chang', 'decad', 'expect', 'fintech']...) from 55 documents (total 466 corpus positions)
# 2020-06-08 19:57:27,143 : INFO : Building graph
# 2020-06-08 19:57:27,144 : INFO : Filling graph
# 2020-06-08 19:57:27,154 : INFO : Removing unreachable nodes of graph
# 2020-06-08 19:57:27,155 : INFO : Pagerank graph
# 2020-06-08 19:57:27,161 : INFO : Sorting pagerank scores
# FINTECH: WHO REGULATES IT AND WHY IT MATTERS
# Fintech: Who Regulates It and Why It Matters Financial institutions have historically been regulated.
# The result has been a strengthening of what is often referred to as Keynesian economics, in honor of John Maynard Keynes, the economist who established the modern basis for how governments need to intervene in the market for it to work properly.
# In the end, it doesn’t really matter if you agree or not with this, because, as Nobel laureate Milton Friedman stated, “We are all Keynesians now.”  Market regulation is a given in our globalized world, and as a result, the question is no longer if regulation is needed.
# Besides illegal activities, globalization has required countries to have a unified financial framework under which they can operate.
# This consensus is the result of important turning points throughout the 20th century that established how the international financial system works.
# What exists is mostly a series of international treaties and agreements between countries that establish the fundamentals of how the global financial system works.
# Understanding FinTech regulation at the national level poses a greater challenge because each country has its own approach.
# As a matter of fact, many countries do not even have a specific regulatory framework for FinTech.
# This results in many FinTech companies adopting the same regulations that apply to traditional financial institutions.
# For the case of the European Union, a series of multilateral institutions regulate financial activities, FinTech included.
# An important reason why many countries do not have FinTech regulations is because regulators usually cannot keep up with innovations.
# Why FinTech Regulation Matters for Your App
# In general, FinTech companies are faced with the challenge of meeting user demands, complying with regulations, and innovating.
# Building great apps that comply with financial regulations is not a responsibility you want to leave in the hands of just anyone.
# It is even better if your development partner can help you implement RegTech in your app; RegTech is a relatively new approach towards regulation that uses technology to maintain compliance.
# FinTech Regulation and App Development
# They need to make sure that their development partners understand the complex regulatory map.
#
#
# THREE FINTECH TRENDS TO WATCH IN 2020
# A great way to face the time consuming challenge of imagining the future is to spot the game changing trends, and as you might have guessed, we have already done this task for you.
# Yes, cryptocurrencies are expected to grow as institutional interoperability increases amongst financial institutions, but it is not the only blockchain use you should be on the look for.
# For 2020 we can expect more from blockchain in the form of digital wallets, asset management technologies, fraud prevention and improved global transactions.
# In general, greater efficiency in the global financial system will be one of the things we can expect as a result from blockchain applications.
# A major opportunity for digital banking is to reduce the time customers spend dealing with financial services.
# As more products and services migrate to an online platform, it is expected that banks will be able to reduce costs and increase efficiency.
# As a result, 2020 can expect digital-only banks to continue consolidating themselves as a serious alternative to traditional banking only as long as they can sort some issues like online fraud prevention and the need to provide excellent online customer support.
# Traditional banks will not disappear anytime soon, so they will need to compete with new products and services while maintaining at least part of their existing branch infrastructure.
# As for blockchain, artificial intelligence (AI) is a major technological trend to keep on the radar throughout 2020.
# It is expected that the user experience through digital banking will be improved to meet specific needs, not only in terms of in-app navigation, but also through better product and service design.
# How countries decide to regulate financial innovation will determine how new products and services are adopted by the market.
#
#
# WHY YOU SHOULD KNOW WHAT BANKING AS A SERVICE IS
# 2020-06-08 19:57:27,176 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2020-06-08 19:57:27,180 : INFO : built Dictionary(301 unique tokens: ['bank', 'evolv', 'exponenti', 'fintech', 'industri']...) from 84 documents (total 642 corpus positions)
# 2020-06-08 19:57:27,182 : INFO : Building graph
# 2020-06-08 19:57:27,183 : INFO : Filling graph
# 2020-06-08 19:57:27,201 : INFO : Removing unreachable nodes of graph
# 2020-06-08 19:57:27,202 : INFO : Pagerank graph
# 2020-06-08 19:57:27,216 : INFO : Sorting pagerank scores
# As new services arise, existing financial companies face the challenge of startups who wish to dethrone them.
# At Koombea, we believe that one of the main frontlines in which this financial competition will evolve is in Banking as a Service.
# This post discusses Banking as a Service and how it is reshaping the FinTech industry.
# BaaS services usually use the data of a legacy bank, which is made available through the possibilities of cloud computing and open banking.
# BaaS allows FinTech companies to make use of users’ financial data for various purposes.
# The user of a FinTech app that gives out loans will first need to authorize the use of his data.
# BaaS can be offered by legacy banks themselves or by third parties who have access to users’ financial data.
# Open Banking is the way in which third parties get access to users’ financial information.
# As mentioned above, users must first give approval to legacy banks, who usually own the data, so that information can be shared with third parties.
# Other techniques exist to guarantee FinTech security, but many startups don’t have the expertise or personnel to develop such solutions.
# FinTech startups are challenging traditional banks.
# As a FinTech startup company, it provides collection tools, payment processing resources, and business process optimization solutions to U.S. lenders and loan servicers.
# Legacy banks need to reinvent themselves in order to compete or cooperate with new players in the FinTech market.
# This has fueled a wave of innovations, particularly in apps that offer specific financial services.
# Bringing great apps to life is a process that many companies in the financial industry don’t understand.
# Our years of experience in FinTech app development have given us the necessary expertise to meet the needs of the financial industry.
