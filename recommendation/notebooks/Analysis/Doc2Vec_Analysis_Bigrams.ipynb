# %% [markdown]
# # Blogs recommendation model using doc2vec

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import logging
import numpy as np
import pandas as pd

from tqdm import tqdm
from bs4 import BeautifulSoup
from utils import *

import matplotlib.pyplot as plt

warnings.filterwarnings("ignore")

tqdm.pandas(desc="Preprocess dataset")
# %matplotlib inline
# Out:
# /home/lasker/anaconda3/envs/.notebook_env/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
logging.basicConfig(format="%(asctime)s : %(levelname)s : %(message)s", level=logging.INFO)
logger = logging.getLogger()

# %% [markdown]
# # Load Dataset

# %%
blogs_df = pd.read_csv("data/blogs_data.csv")

# %%
blogs_df.head() # This data is already preprocess and normalize in English
# Out:
#      id                                              title  \
# 0  5173               Why Scalability Matters for Your App
# 1  5174  Is a Scrum Agile Development Process Right for...
# 2  5175  How to Make Your App Irresistible Through User...
# 3  5176  5 Product Manager MUSTS for Creating a Success...
# 4  5177  7 Key Questions to Ask Your Prospective App De...
#
#                                              content  \
# 0  Building an app is an extensive process. From ...
# 1  A Brief History of Scrum Agile Development: \n...
# 2  Guessing is a part of life—and it’s necessary....
# 3  Product management is a tough job. You must tr...
# 4  From the moment you decide to move forward wit...
#
#                                                 slug  \
# 0               why-scalability-matters-for-your-app
# 1  is-a-scrum-agile-development-process-right-for...
# 2  how-to-make-your-app-irresistible-through-user...
# 3  5-product-manager-musts-for-creating-a-success...
# 4  7-key-questions-to-ask-prospective-app-develop...
#
#                                                 data lang  \
# 0  Why Scalability Matters for Your App Building ...   en
# 1  Is a Scrum Agile Development Process Right for...   en
# 2  How to Make Your App Irresistible Through User...   en
# 3  5 Product Manager MUSTS for Creating a Success...   en
# 4  7 Key Questions to Ask Your Prospective App De...   en
#
#                                       normalize_data
# 0  Why Scalability Matters for Your App Building ...
# 1  Is a Scrum Agile Development Process Right for...
# 2  How to Make Your App Irresistible Through User...
# 3  5 Product Manager MUSTS for Creating a Success...
# 4  7 Key Questions to Ask Your Prospective App De...

# %%
print(blogs_df["normalize_data"][0])
# Out:
# Why Scalability Matters for Your App Building an app is an extensive process. From a fresh idea to a marketable product, the journey is filled with ups and downs. So, when you (hopefully) build that successful app, the last thing you want is for it to hit a dead end.
# However, that’s, unfortunately, the way it usually goes. You might think that accelerated growth is totally positive, as users are downloading your app at a record rate. But, an app that isn’t designed and developed to seamlessly handle this explosive growth will eventually end up being a failure.
# Consider this: is your app, as it stands today, able to scale up to exponential growth? If you have any doubts, you need to seriously consider this scalability issue.
#
# What is app scalability?
# Scalability is the ability of your app to handle a growing number of customers, clients and/or users. It also pertains to the ability of your current or future developer to maintain the app. Consider the possibility that your app isn’t currently scalable. If it’s not, be prepared to scramble to add necessary additional features without the flexible coding that keeps your app running smoothly.
# What are the benefits of a scalable app?
# You need to start your whole development process with scalability as a priority. After all, you want to assume rapid success when your app hits the market, and you certainly don’t want your hot product going belly up at the worst possible time. Here are some benefits:
# -Maintain a good user experience for your app over thousands of users
# Viral marketing can result in instant success—and a huge influx of traffic. But it’s usually a bit unpredictable. If your app is scalable, then you can accommodate this rapid growth with zero downtime—and without sacrificing user experience. When it comes to your marketing campaign, you can be confident about your app’s reliability.
# -Take advantage of holidays and other events (Olympics, Christmas, Black Friday, etc.) when app usage increases
# You can scale up and offer special deals for the holidays and other events—or, just be well-prepared for a quick increase in traffic. Scaling for a “Christmas” type moment can be frightening—you’re forced to confront the design decisions you made in the early stages of the app. If your app has hidden weaknesses, a massive new group of users will reveal them.
# -You won’t be tied to the original developer
# You won’t be held hostage by code so intricate that it can only be maintained by the developer who created it. You’ll be flexible, and able to hand off the project to other developers if necessary.
# -More potential for growth, a higher ROI, and more positive user feedback
# Wise app development allows for rapid growth. With comprehensive scalability testing, you can identify bugs and glitches before your users do…saving you hundreds of bad reviews.
# How to determine if your app is scalable
# Your app needs to be scalable from the start, way before it’s launched to the public. And the only way to truly know if the app can handle rapid scaling is by extensive testing. The reason scalability testing is necessary is that you need to know if your app can handle the enormous workload ahead while avoiding costly glitches and constant updates. The only way to truly know it’s ready is to consistently and comprehensively test it.
# Imagine taking a car to market without testing its durability, performance, brakes, and its ability to take tight turns. What if the safety features weren’t good enough to protect people in accidents? What if the engine doesn’t start on the showroom floor? Your brand would be tarnished.
# Applications are the same way. Even if your customers want all the benefits of using your app, they’ll be turned away by simple scalability and performance issues.
# Load testing is the process of putting demand on an app and measuring its response. No matter how many tests you run, load testing is really the only one way to determine if your software can handle the actual demands your thousands (or millions!) of end users will place on it.
# Load tests are specifically designed to assess response times and resource usage, while clearly pinpointing your app’s breaking point.
# Performance testing refers to testing done to analyze and improve your app’s performance. This sort of test is conducted to determine the status of your app’s active performance by carefully examining data mined from the testing process, and making your resource consumption optimal.
# Scalability testing refers to performance testing centered around understanding the scalability of an application. The goal is to determine the breaking point when the application stops scaling, and find the reason for it.
# Plan to scale from the beginning
# Before you start the development phase, you should be prepared to answer these important questions:
#
#
# How many users would you expect to use your new app within the year?
# Do you have a data collection plan?
#
# How long can all your customers fit on one server?
# What can you do when you have more customers or data than that?
#
# By assuring that your app is fully scalable from the beginning, you can absorb exponential growth with a minimum of downtime, all while optimizing user experience.
# Conclusion
# Scalability is crucial for your app’s success. When your app is scalable, it can accommodate growth, provide a good user experience for new users, and give you a better ROI. If you want to serve thousands or even millions with your app, you need to plan for it from the beginning.
# The ultimate purpose of scalability testing is to push the current app beyond its breaking point. Your team can then pinpoint that crucial moment, reverse engineer the problem, and make the app scalable and functional.
# Are you building a scalable application? Scaling an existing app? What challenges have you faced so far? Shoot us an email at mvp@koombea.com and let us know!
# Want more great tips to help you build a successful application? Subscribe below!
# Author: @keswanberg

# %% [markdown]
# # Preprocess data for training

# %%
regex = get_regex_expression()
regex
# Out:
# '(https?:\\/\\/.*[\\r\\n])|(\\#[^\\s]*)|(\\@[^\\s]*)|(author)|(\\S*@\\S+)|([^a-zA-Z0-9À-ÿ\\u00f1\\u00d1\\s])'

# %%
example = preprocess_data(blogs_df["normalize_data"][0], regex, 
                          removing_stops=True, lemmatize=True)
print(example)
# Out:
# ['scalability', 'matter', 'app', 'build', 'app', 'extensive', 'process', 'fresh', 'idea', 'marketable', 'product', 'journey', 'fill', 'up', 'down', 'hopefully', 'build', 'successful', 'app', 'thing', 'want', 'hit', 'dead', 'end', 'unfortunately', 'way', 'usually', 'go', 'think', 'accelerated', 'growth', 'totally', 'positive', 'user', 'download', 'app', 'record', 'rate', 'app', 'isn', 'design', 'develop', 'seamlessly', 'handle', 'explosive', 'growth', 'eventually', 'end', 'failure', 'consider', 'app', 'stand', 'today', 'able', 'scale', 'exponential', 'growth', 'doubt', 'need', 'seriously', 'consider', 'scalability', 'issue', 'app', 'scalability', 'scalability', 'ability', 'app', 'handle', 'grow', 'number', 'customer', 'client', 'user', 'pertain', 'ability', 'current', 'future', 'developer', 'maintain', 'app', 'consider', 'possibility', 'app', 'isn', 'currently', 'scalable', 'prepared', 'scramble', 'add', 'necessary', 'additional', 'feature', 'flexible', 'coding', 'keep', 'app', 'run', 'smoothly', 'benefit', 'scalable', 'app', 'need', 'start', 'development', 'process', 'scalability', 'priority', 'want', 'assume', 'rapid', 'success', 'app', 'hit', 'market', 'certainly', 'don', 'want', 'hot', 'product', 'go', 'belly', 'bad', 'possible', 'time', 'benefit', 'maintain', 'good', 'user', 'experience', 'app', 'thousand', 'user', 'viral', 'marketing', 'result', 'instant', 'success', 'huge', 'influx', 'traffic', 'usually', 'bit', 'unpredictable', 'app', 'scalable', 'accommodate', 'rapid', 'growth', 'downtime', 'sacrifice', 'user', 'experience', 'come', 'marketing', 'campaign', 'confident', 'app', 'reliability', 'advantage', 'holiday', 'event', 'olympics', 'christmas', 'black', 'friday', 'etc', 'app', 'usage', 'increase', 'scale', 'offer', 'special', 'deal', 'holiday', 'event', 'prepared', 'quick', 'increase', 'traffic', 'scale', 'christmas', 'type', 'moment', 'frightening', 'force', 'confront', 'design', 'decision', 'early', 'stage', 'app', 'app', 'hide', 'weakness', 'massive', 'new', 'group', 'user', 'reveal', 'win', 'tie', 'original', 'developer', 'win', 'hold', 'hostage', 'code', 'intricate', 'maintain', 'developer', 'create', 'will', 'flexible', 'able', 'hand', 'project', 'developer', 'necessary', 'potential', 'growth', 'high', 'roi', 'positive', 'user', 'feedback', 'wise', 'app', 'development', 'allow', 'rapid', 'growth', 'comprehensive', 'scalability', 'testing', 'identify', 'bug', 'glitch', 'user', 'save', 'hundred', 'bad', 'review', 'determine', 'app', 'scalable', 'app', 'need', 'scalable', 'start', 'way', 'launch', 'public', 'way', 'truly', 'know', 'app', 'handle', 'rapid', 'scaling', 'extensive', 'testing', 'reason', 'scalability', 'testing', 'necessary', 'need', 'know', 'app', 'handle', 'enormous', 'workload', 'ahead', 'avoid', 'costly', 'glitch', 'constant', 'update', 'way', 'truly', 'know', 'ready', 'consistently', 'comprehensively', 'test', 'imagine', 'take', 'car', 'market', 'test', 'durability', 'performance', 'brake', 'ability', 'tight', 'turn', 'safety', 'feature', 'weren', 'good', 'protect', 'people', 'accident', 'engine', 'doesn', 'start', 'showroom', 'floor', 'brand', 'tarnish', 'application', 'way', 'customer', 'want', 'benefit', 'app', 'will', 'turn', 'away', 'simple', 'scalability', 'performance', 'issue', 'load', 'testing', 'process', 'put', 'demand', 'app', 'measure', 'response', 'matter', 'test', 'run', 'load', 'testing', 'way', 'determine', 'software', 'handle', 'actual', 'demand', 'thousand', 'million', 'end', 'user', 'place', 'load', 'test', 'specifically', 'design', 'assess', 'response', 'time', 'resource', 'usage', 'clearly', 'pinpoint', 'app', 'breaking', 'point', 'performance', 'testing', 'refer', 'testing', 'analyze', 'improve', 'app', 'performance', 'sort', 'test', 'conduct', 'determine', 'status', 'app', 'active', 'performance', 'carefully', 'examine', 'datum', 'mine', 'testing', 'process', 'make', 'resource', 'consumption', 'optimal', 'scalability', 'testing', 'refer', 'performance', 'testing', 'cente ...

# %%
# Train data doing lemmatization and removing stopswords
train_data = [preprocess_data(normalize_data, regex, True, True) 
                for normalize_data in tqdm(blogs_df["normalize_data"].values)]
# Out:
# 100%|██████████| 458/458 [00:47<00:00,  9.60it/s]

# %%
print(train_data[0])
# Out:
# ['scalability', 'matter', 'app', 'build', 'app', 'extensive', 'process', 'fresh', 'idea', 'marketable', 'product', 'journey', 'fill', 'up', 'down', 'hopefully', 'build', 'successful', 'app', 'thing', 'want', 'hit', 'dead', 'end', 'unfortunately', 'way', 'usually', 'go', 'think', 'accelerated', 'growth', 'totally', 'positive', 'user', 'download', 'app', 'record', 'rate', 'app', 'isn', 'design', 'develop', 'seamlessly', 'handle', 'explosive', 'growth', 'eventually', 'end', 'failure', 'consider', 'app', 'stand', 'today', 'able', 'scale', 'exponential', 'growth', 'doubt', 'need', 'seriously', 'consider', 'scalability', 'issue', 'app', 'scalability', 'scalability', 'ability', 'app', 'handle', 'grow', 'number', 'customer', 'client', 'user', 'pertain', 'ability', 'current', 'future', 'developer', 'maintain', 'app', 'consider', 'possibility', 'app', 'isn', 'currently', 'scalable', 'prepared', 'scramble', 'add', 'necessary', 'additional', 'feature', 'flexible', 'coding', 'keep', 'app', 'run', 'smoothly', 'benefit', 'scalable', 'app', 'need', 'start', 'development', 'process', 'scalability', 'priority', 'want', 'assume', 'rapid', 'success', 'app', 'hit', 'market', 'certainly', 'don', 'want', 'hot', 'product', 'go', 'belly', 'bad', 'possible', 'time', 'benefit', 'maintain', 'good', 'user', 'experience', 'app', 'thousand', 'user', 'viral', 'marketing', 'result', 'instant', 'success', 'huge', 'influx', 'traffic', 'usually', 'bit', 'unpredictable', 'app', 'scalable', 'accommodate', 'rapid', 'growth', 'downtime', 'sacrifice', 'user', 'experience', 'come', 'marketing', 'campaign', 'confident', 'app', 'reliability', 'advantage', 'holiday', 'event', 'olympics', 'christmas', 'black', 'friday', 'etc', 'app', 'usage', 'increase', 'scale', 'offer', 'special', 'deal', 'holiday', 'event', 'prepared', 'quick', 'increase', 'traffic', 'scale', 'christmas', 'type', 'moment', 'frightening', 'force', 'confront', 'design', 'decision', 'early', 'stage', 'app', 'app', 'hide', 'weakness', 'massive', 'new', 'group', 'user', 'reveal', 'win', 'tie', 'original', 'developer', 'win', 'hold', 'hostage', 'code', 'intricate', 'maintain', 'developer', 'create', 'will', 'flexible', 'able', 'hand', 'project', 'developer', 'necessary', 'potential', 'growth', 'high', 'roi', 'positive', 'user', 'feedback', 'wise', 'app', 'development', 'allow', 'rapid', 'growth', 'comprehensive', 'scalability', 'testing', 'identify', 'bug', 'glitch', 'user', 'save', 'hundred', 'bad', 'review', 'determine', 'app', 'scalable', 'app', 'need', 'scalable', 'start', 'way', 'launch', 'public', 'way', 'truly', 'know', 'app', 'handle', 'rapid', 'scaling', 'extensive', 'testing', 'reason', 'scalability', 'testing', 'necessary', 'need', 'know', 'app', 'handle', 'enormous', 'workload', 'ahead', 'avoid', 'costly', 'glitch', 'constant', 'update', 'way', 'truly', 'know', 'ready', 'consistently', 'comprehensively', 'test', 'imagine', 'take', 'car', 'market', 'test', 'durability', 'performance', 'brake', 'ability', 'tight', 'turn', 'safety', 'feature', 'weren', 'good', 'protect', 'people', 'accident', 'engine', 'doesn', 'start', 'showroom', 'floor', 'brand', 'tarnish', 'application', 'way', 'customer', 'want', 'benefit', 'app', 'will', 'turn', 'away', 'simple', 'scalability', 'performance', 'issue', 'load', 'testing', 'process', 'put', 'demand', 'app', 'measure', 'response', 'matter', 'test', 'run', 'load', 'testing', 'way', 'determine', 'software', 'handle', 'actual', 'demand', 'thousand', 'million', 'end', 'user', 'place', 'load', 'test', 'specifically', 'design', 'assess', 'response', 'time', 'resource', 'usage', 'clearly', 'pinpoint', 'app', 'breaking', 'point', 'performance', 'testing', 'refer', 'testing', 'analyze', 'improve', 'app', 'performance', 'sort', 'test', 'conduct', 'determine', 'status', 'app', 'active', 'performance', 'carefully', 'examine', 'datum', 'mine', 'testing', 'process', 'make', 'resource', 'consumption', 'optimal', 'scalability', 'testing', 'refer', 'performance', 'testing', 'cente ...

# %% [markdown]
# # Get bigrams

# %%
from gensim.models import Phrases

bigrams = Phrases(train_data, min_count=1, threshold=5)
# Out:
# 2020-06-09 10:41:46,444 : INFO : collecting all words and their counts
# 2020-06-09 10:41:46,445 : INFO : PROGRESS: at sentence #0, processed 0 words and 0 word types
# 2020-06-09 10:41:46,704 : INFO : collected 159713 word types from a corpus of 224885 words (unigram + bigrams) and 458 sentences
# 2020-06-09 10:41:46,704 : INFO : using 159713 counts as vocab in Phrases<0 vocab, min_count=1, threshold=5, max_vocab_size=40000000>

# %%
print(bigrams[train_data[0]])
# Out:
# ['scalability', 'matter', 'app', 'build', 'app', 'extensive_process', 'fresh', 'idea', 'marketable_product', 'journey', 'fill', 'up_down', 'hopefully_build', 'successful_app', 'thing', 'want_hit', 'dead_end', 'unfortunately', 'way', 'usually', 'go', 'think', 'accelerated', 'growth', 'totally', 'positive', 'user', 'download', 'app', 'record', 'rate', 'app', 'isn', 'design', 'develop', 'seamlessly', 'handle_explosive', 'growth', 'eventually', 'end', 'failure', 'consider', 'app', 'stand', 'today', 'able_scale', 'exponential_growth', 'doubt', 'need_seriously', 'consider_scalability', 'issue', 'app', 'scalability_scalability', 'ability', 'app', 'handle_grow', 'number', 'customer', 'client', 'user', 'pertain', 'ability', 'current', 'future', 'developer', 'maintain', 'app', 'consider', 'possibility', 'app', 'isn', 'currently', 'scalable', 'prepared', 'scramble', 'add', 'necessary', 'additional_feature', 'flexible', 'coding', 'keep', 'app', 'run_smoothly', 'benefit', 'scalable', 'app', 'need', 'start', 'development_process', 'scalability', 'priority', 'want', 'assume', 'rapid_success', 'app', 'hit_market', 'certainly_don', 'want', 'hot', 'product', 'go', 'belly', 'bad', 'possible', 'time', 'benefit', 'maintain', 'good', 'user_experience', 'app', 'thousand', 'user', 'viral', 'marketing', 'result', 'instant_success', 'huge_influx', 'traffic', 'usually', 'bit', 'unpredictable', 'app', 'scalable_accommodate', 'rapid_growth', 'downtime', 'sacrifice', 'user_experience', 'come', 'marketing_campaign', 'confident', 'app', 'reliability', 'advantage', 'holiday_event', 'olympics', 'christmas', 'black_friday', 'etc', 'app', 'usage_increase', 'scale', 'offer_special', 'deal', 'holiday_event', 'prepared', 'quick', 'increase_traffic', 'scale', 'christmas', 'type', 'moment', 'frightening', 'force', 'confront', 'design', 'decision', 'early_stage', 'app', 'app', 'hide', 'weakness', 'massive', 'new', 'group', 'user', 'reveal', 'win', 'tie', 'original_developer', 'win_hold', 'hostage', 'code', 'intricate', 'maintain', 'developer', 'create', 'will', 'flexible', 'able', 'hand', 'project', 'developer', 'necessary', 'potential', 'growth', 'high', 'roi', 'positive', 'user', 'feedback', 'wise', 'app_development', 'allow_rapid', 'growth', 'comprehensive', 'scalability_testing', 'identify_bug', 'glitch', 'user', 'save', 'hundred', 'bad', 'review', 'determine', 'app', 'scalable', 'app', 'need', 'scalable', 'start', 'way', 'launch', 'public', 'way', 'truly_know', 'app', 'handle', 'rapid', 'scaling', 'extensive_testing', 'reason', 'scalability_testing', 'necessary', 'need_know', 'app', 'handle_enormous', 'workload', 'ahead', 'avoid_costly', 'glitch', 'constant_update', 'way', 'truly_know', 'ready', 'consistently', 'comprehensively', 'test', 'imagine', 'take', 'car', 'market', 'test', 'durability', 'performance', 'brake', 'ability', 'tight', 'turn', 'safety_feature', 'weren_good', 'protect', 'people', 'accident', 'engine', 'doesn', 'start', 'showroom', 'floor', 'brand', 'tarnish', 'application', 'way', 'customer', 'want', 'benefit', 'app', 'will', 'turn_away', 'simple', 'scalability', 'performance_issue', 'load_testing', 'process', 'put', 'demand', 'app', 'measure', 'response', 'matter', 'test_run', 'load_testing', 'way', 'determine', 'software_handle', 'actual_demand', 'thousand_million', 'end_user', 'place', 'load_test', 'specifically_design', 'assess', 'response', 'time_resource', 'usage', 'clearly', 'pinpoint', 'app', 'breaking_point', 'performance_testing', 'refer', 'testing', 'analyze', 'improve', 'app', 'performance', 'sort', 'test', 'conduct', 'determine', 'status', 'app', 'active', 'performance', 'carefully', 'examine', 'datum', 'mine', 'testing_process', 'make', 'resource_consumption', 'optimal', 'scalability_testing', 'refer', 'performance_testing', 'center', 'understand', 'scalability', 'application', 'goal', 'determine', 'breaking_point', 'application', 'stop', 'scale', 'find', 'reason', 'plan', 'scale', 'beginning', 'start', 'development_phase', 'prepar ...

# %% [markdown]
# # Doc2Vec model with gensim

# %% [markdown]
# ```
# Parameters
# ----------
# documents : iterable of list of :class:`~gensim.models.doc2vec.TaggedDocument`
#
# dm : {1,0}, optional
#     Defines the training algorithm. If `dm=1`, 'distributed memory' (PV-DM) is used.
#     Otherwise, `distributed bag of words` (PV-DBOW) is employed.
#
# vector_size : int, optional
#     Dimensionality of the feature vectors.
#
# window : int, optional
#     The maximum distance between the current and predicted word within a sentence.
#
# alpha : float, optional
#     The initial learning rate.
#
# min_alpha : float, optional
#     Learning rate will linearly drop to `min_alpha` as training progresses.
#
# min_count : int, optional
#     Ignores all words with total frequency lower than this.
#
# max_vocab_size : int, optional
#     Limits the RAM during vocabulary building; if there are more unique
#     words than this, then prune the infrequent ones. Every 10 million word types need about 1GB of RAM.
#
# sample : float, optional
#     The threshold for configuring which higher-frequency words are randomly downsampled,
#     useful range is (0, 1e-5).
#
# workers : int, optional
#     Use these many worker threads to train the model (=faster training with multicore machines).
#
# epochs : int, optional
#     Number of iterations (epochs) over the corpus.
#
# hs : {1,0}, optional
#     If 1, hierarchical softmax will be used for model training.
#     If set to 0, and `negative` is non-zero, negative sampling will be used.
#
# negative : int, optional
#     If > 0, negative sampling will be used, the int for negative specifies how many "noise words"
#     should be drawn (usually between 5-20).
#     If set to 0, no negative sampling is used.
#
# ns_exponent : float, optional
#     The exponent used to shape the negative sampling distribution. A value of 1.0 samples exactly in
#     proportion to the frequencies, 0.0 samples all words equally, while a negative value samples low
#     frequency words more than high-frequency words.
#
# dm_mean : {1,0}, optional
#     If 0 , use the sum of the context word vectors. If 1, use the mean.
#     Only applies when `dm` is used in non-concatenative mode.
#
# dm_concat : {1,0}, optional
#     If 1, use concatenation of context vectors rather than sum/average;
#     Note concatenation results in a much-larger model, as the input
#     is no longer the size of one (sampled or arithmetically combined) word vector, but the
#     size of the tag(s) and all words in the context strung together.
#
# dm_tag_count : int, optional
#     Expected constant number of document tags per document, when using
#     dm_concat mode.
#
# dbow_words : {1,0}, optional
#     If set to 1 trains word-vectors (in skip-gram fashion) simultaneous with DBOW
#     doc-vector training; If 0, only trains doc-vectors (faster).
# ```

# %% [markdown]
# ## Prepare the data

# %%
from gensim.models.doc2vec import Doc2Vec, TaggedDocument

# %%
train_data = [text_vector for text_vector in tqdm(bigrams[train_data])]
# Out:
# 100%|██████████| 458/458 [00:00<00:00, 869.58it/s]

# %%
blogs = [TaggedDocument(blog, [i]) for i, blog in enumerate(train_data)]

# %% [markdown]
# ## Hyperparameters

# %%
import multiprocessing
cpu_counts = multiprocessing.cpu_count()

# %%
hyperparameters = {"dm":1, "size":300, "window":5, "sample": 1e-4, 
                   "workers": cpu_counts, "epochs": 140, "hs":0, "negative":15,
                   "ns_exponent": -0.5, "dbow_words":1}

# %%
doc2vec_model = Doc2Vec(**hyperparameters)

# %% [markdown]
# ## Build vocab

# %%
doc2vec_model.build_vocab(blogs)
# Out:
# 2020-06-09 10:42:17,052 : INFO : collecting all words and their counts
# 2020-06-09 10:42:17,053 : INFO : PROGRESS: at example #0, processed 0 words (0/s), 0 word types, 0 tags
# 2020-06-09 10:42:17,087 : INFO : collected 21009 word types and 458 unique tags from a corpus of 458 examples and 183555 words
# 2020-06-09 10:42:17,088 : INFO : Loading a fresh vocabulary
# 2020-06-09 10:42:17,176 : INFO : effective_min_count=5 retains 4948 unique words (23% of original 21009, drops 16061)
# 2020-06-09 10:42:17,177 : INFO : effective_min_count=5 leaves 152294 word corpus (82% of original 183555, drops 31261)
# 2020-06-09 10:42:17,195 : INFO : deleting the raw counts dictionary of 21009 items
# 2020-06-09 10:42:17,196 : INFO : sample=0.0001 downsamples 746 most-common words
# 2020-06-09 10:42:17,196 : INFO : downsampling leaves estimated 90845 word corpus (59.7% of prior 152294)
# 2020-06-09 10:42:17,210 : INFO : estimated required memory for 4948 words and 300 dimensions: 14898800 bytes
# 2020-06-09 10:42:17,211 : INFO : resetting layer weights

# %% [markdown]
# ## Train doc2vec model

# %%
doc2vec_model.train(blogs, total_examples=doc2vec_model.corpus_count, 
                   epochs=doc2vec_model.epochs)
# Out:
# 2020-06-09 10:42:18,179 : INFO : training model with 8 workers on 4948 vocabulary and 300 features, using sg=0 hs=0 sample=0.0001 negative=15 window=5
# 2020-06-09 10:42:18,365 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:18,367 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:18,373 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:18,377 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:18,386 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:18,405 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:18,410 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:18,424 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:18,424 : INFO : EPOCH - 1 : training on 183555 raw words (91396 effective words) took 0.2s, 378764 effective words/s
# 2020-06-09 10:42:18,595 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:18,606 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:18,608 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:18,618 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:18,638 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:18,646 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:18,652 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:18,657 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:18,658 : INFO : EPOCH - 2 : training on 183555 raw words (91335 effective words) took 0.2s, 400022 effective words/s
# 2020-06-09 10:42:18,858 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:18,860 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:18,865 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:18,868 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:18,881 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:18,900 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:18,903 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:18,911 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:18,911 : INFO : EPOCH - 3 : training on 183555 raw words (91379 effective words) took 0.3s, 365237 effective words/s
# 2020-06-09 10:42:19,089 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:19,091 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:19,094 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:19,109 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:19,114 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:19,129 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:19,135 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:19,150 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:19,150 : INFO : EPOCH - 4 : training on 183555 raw words (91345 effective words) took 0.2s, 388198 effective words/s
# 2020-06-09 10:42:19,334 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:19,335 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:19,337 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:19,345 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:19,347 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:19,372 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:19,379 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:19,389 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:19,389 : INFO : EPOCH - 5 : training on 183555 raw words (90964 effective words) took 0.2s, 387666 effective words/s
# 2020-06-09 10:42:19,567 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:19,574 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:19,575 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:19,580 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:19,602 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:19,613 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:19,617 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:19,620 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:19,621 : INFO : EPOCH - 6 : training on 183555 raw words (91382 effective words) took 0.2s, 405102 effective words/s
# 2020-06-09 10:42:19,787 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:19,800 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:19,802 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:19,806 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:19,820 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:19,838 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:19,842 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:19,847 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:19,848 : INFO : EPOCH - 7 : training on 183555 raw words (91339 effective words) took 0.2s, 406320 effective words/s
# 2020-06-09 10:42:20,034 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:20,040 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:20,045 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:20,046 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:20,061 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:20,077 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:20,081 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:20,084 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:20,084 : INFO : EPOCH - 8 : training on 183555 raw words (91529 effective words) took 0.2s, 392504 effective words/s
# 2020-06-09 10:42:20,253 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:20,260 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:20,261 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:20,268 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:20,285 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:20,299 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:20,300 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:20,307 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:20,308 : INFO : EPOCH - 9 : training on 183555 raw words (91228 effective words) took 0.2s, 418219 effective words/s
# 2020-06-09 10:42:20,488 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:20,494 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:20,496 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:20,510 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:20,512 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:20,535 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:20,536 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:20,549 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:20,549 : INFO : EPOCH - 10 : training on 183555 raw words (90980 effective words) took 0.2s, 380831 effective words/s
# 2020-06-09 10:42:20,735 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:20,741 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:20,746 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:20,748 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:20,764 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:20,774 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:20,778 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:20,784 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:20,784 : INFO : EPOCH - 11 : training on 183555 raw words (91249 effective words) took 0.2s, 399940 effective words/s
# 2020-06-09 10:42:20,953 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:20,960 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:20,963 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:20,966 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:20,975 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:20,995 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:20,995 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:21,000 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:21,001 : INFO : EPOCH - 12 : training on 183555 raw words (91397 effective words) took 0.2s, 426719 effective words/s
# 2020-06-09 10:42:21,185 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:21,189 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:21,194 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:21,199 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:21,204 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:21,223 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:21,227 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:21,233 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:21,233 : INFO : EPOCH - 13 : training on 183555 raw words (91233 effective words) took 0.2s, 397209 effective words/s
# 2020-06-09 10:42:21,401 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:21,407 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:21,412 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:21,416 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:21,432 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:21,443 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:21,446 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:21,453 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:21,453 : INFO : EPOCH - 14 : training on 183555 raw words (91310 effective words) took 0.2s, 420545 effective words/s
# 2020-06-09 10:42:21,641 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:21,644 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:21,651 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:21,655 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:21,667 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:21,680 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:21,682 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:21,690 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:21,691 : INFO : EPOCH - 15 : training on 183555 raw words (91388 effective words) took 0.2s, 389080 effective words/s
# 2020-06-09 10:42:21,862 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:21,863 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:21,867 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:21,868 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:21,884 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:21,907 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:21,908 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:21,911 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:21,912 : INFO : EPOCH - 16 : training on 183555 raw words (91270 effective words) took 0.2s, 420475 effective words/s
# 2020-06-09 10:42:22,080 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:22,087 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:22,091 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:22,095 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:22,106 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:22,124 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:22,132 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:22,140 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:22,141 : INFO : EPOCH - 17 : training on 183555 raw words (91367 effective words) took 0.2s, 405216 effective words/s
# 2020-06-09 10:42:22,346 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:22,357 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:22,362 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:22,369 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:22,377 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:22,397 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:22,401 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:22,408 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:22,409 : INFO : EPOCH - 18 : training on 183555 raw words (91460 effective words) took 0.3s, 345874 effective words/s
# 2020-06-09 10:42:22,601 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:22,603 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:22,610 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:22,612 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:22,622 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:22,642 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:22,649 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:22,649 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:22,650 : INFO : EPOCH - 19 : training on 183555 raw words (91143 effective words) took 0.2s, 383872 effective words/s
# 2020-06-09 10:42:22,849 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:22,857 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:22,863 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:22,874 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:22,888 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:22,898 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:22,901 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:22,908 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:22,909 : INFO : EPOCH - 20 : training on 183555 raw words (91031 effective words) took 0.3s, 354347 effective words/s
# 2020-06-09 10:42:23,167 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:23,169 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:23,171 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:23,178 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:23,184 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:23,208 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:23,210 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:23,217 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:23,218 : INFO : EPOCH - 21 : training on 183555 raw words (91473 effective words) took 0.3s, 300322 effective words/s
# 2020-06-09 10:42:23,447 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:23,449 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:23,455 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:23,461 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:23,463 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:23,492 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:23,501 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:23,510 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:23,511 : INFO : EPOCH - 22 : training on 183555 raw words (91342 effective words) took 0.3s, 317939 effective words/s
# 2020-06-09 10:42:23,774 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:23,776 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:23,789 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:23,791 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:23,812 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:23,825 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:23,827 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:23,833 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:23,833 : INFO : EPOCH - 23 : training on 183555 raw words (91393 effective words) took 0.3s, 292444 effective words/s
# 2020-06-09 10:42:24,056 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:24,060 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:24,062 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:24,065 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:24,072 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:24,091 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:24,100 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:24,106 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:24,107 : INFO : EPOCH - 24 : training on 183555 raw words (91406 effective words) took 0.3s, 341445 effective words/s
# 2020-06-09 10:42:24,279 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:24,282 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:24,287 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:24,289 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:24,295 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:24,324 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:24,325 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:24,327 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:24,327 : INFO : EPOCH - 25 : training on 183555 raw words (91349 effective words) took 0.2s, 426273 effective words/s
# 2020-06-09 10:42:24,498 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:24,506 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:24,507 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:24,509 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:24,518 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:24,538 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:24,539 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:24,544 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:24,544 : INFO : EPOCH - 26 : training on 183555 raw words (91251 effective words) took 0.2s, 425275 effective words/s
# 2020-06-09 10:42:24,719 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:24,727 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:24,731 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:24,732 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:24,736 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:24,755 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:24,758 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:24,769 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:24,770 : INFO : EPOCH - 27 : training on 183555 raw words (91128 effective words) took 0.2s, 410864 effective words/s
# 2020-06-09 10:42:24,938 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:24,951 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:24,953 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:24,957 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:24,968 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:24,980 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:24,983 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:24,992 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:24,992 : INFO : EPOCH - 28 : training on 183555 raw words (91253 effective words) took 0.2s, 415912 effective words/s
# 2020-06-09 10:42:25,178 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:25,183 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:25,185 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:25,191 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:25,206 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:25,221 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:25,231 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:25,237 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:25,237 : INFO : EPOCH - 29 : training on 183555 raw words (91335 effective words) took 0.2s, 378741 effective words/s
# 2020-06-09 10:42:25,414 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:25,415 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:25,420 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:25,422 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:25,434 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:25,449 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:25,452 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:25,455 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:25,456 : INFO : EPOCH - 30 : training on 183555 raw words (91586 effective words) took 0.2s, 423517 effective words/s
# 2020-06-09 10:42:25,637 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:25,645 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:25,649 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:25,656 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:25,658 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:25,681 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:25,682 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:25,687 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:25,687 : INFO : EPOCH - 31 : training on 183555 raw words (91169 effective words) took 0.2s, 398257 effective words/s
# 2020-06-09 10:42:25,872 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:25,883 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:25,888 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:25,889 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:25,898 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:25,916 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:25,919 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:25,925 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:25,926 : INFO : EPOCH - 32 : training on 183555 raw words (91475 effective words) took 0.2s, 390199 effective words/s
# 2020-06-09 10:42:26,105 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:26,116 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:26,118 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:26,124 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:26,135 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:26,161 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:26,162 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:26,163 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:26,164 : INFO : EPOCH - 33 : training on 183555 raw words (91079 effective words) took 0.2s, 388113 effective words/s
# 2020-06-09 10:42:26,372 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:26,373 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:26,375 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:26,378 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:26,401 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:26,405 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:26,409 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:26,415 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:26,416 : INFO : EPOCH - 34 : training on 183555 raw words (91064 effective words) took 0.2s, 371410 effective words/s
# 2020-06-09 10:42:26,592 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:26,601 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:26,613 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:26,628 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:26,642 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:26,664 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:26,670 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:26,672 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:26,673 : INFO : EPOCH - 35 : training on 183555 raw words (91357 effective words) took 0.3s, 358153 effective words/s
# 2020-06-09 10:42:26,832 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:26,835 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:26,841 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:26,846 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:26,856 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:26,870 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:26,873 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:26,879 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:26,880 : INFO : EPOCH - 36 : training on 183555 raw words (91174 effective words) took 0.2s, 446864 effective words/s
# 2020-06-09 10:42:27,061 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:27,067 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:27,070 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:27,072 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:27,080 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:27,100 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:27,113 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:27,118 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:27,118 : INFO : EPOCH - 37 : training on 183555 raw words (91462 effective words) took 0.2s, 387871 effective words/s
# 2020-06-09 10:42:27,279 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:27,281 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:27,286 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:27,289 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:27,302 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:27,319 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:27,320 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:27,330 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:27,331 : INFO : EPOCH - 38 : training on 183555 raw words (91480 effective words) took 0.2s, 436932 effective words/s
# 2020-06-09 10:42:27,565 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:27,577 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:27,578 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:27,582 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:27,587 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:27,604 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:27,605 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:27,609 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:27,610 : INFO : EPOCH - 39 : training on 183555 raw words (91371 effective words) took 0.3s, 332210 effective words/s
# 2020-06-09 10:42:27,795 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:27,799 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:27,806 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:27,811 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:27,821 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:27,836 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:27,838 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:27,844 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:27,845 : INFO : EPOCH - 40 : training on 183555 raw words (91301 effective words) took 0.2s, 392644 effective words/s
# 2020-06-09 10:42:28,014 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:28,023 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:28,028 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:28,032 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:28,037 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:28,053 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:28,056 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:28,060 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:28,061 : INFO : EPOCH - 41 : training on 183555 raw words (91081 effective words) took 0.2s, 428176 effective words/s
# 2020-06-09 10:42:28,223 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:28,229 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:28,234 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:28,243 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:28,248 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:28,265 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:28,266 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:28,272 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:28,272 : INFO : EPOCH - 42 : training on 183555 raw words (91586 effective words) took 0.2s, 444671 effective words/s
# 2020-06-09 10:42:28,435 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:28,437 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:28,442 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:28,443 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:28,457 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:28,474 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:28,476 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:28,481 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:28,481 : INFO : EPOCH - 43 : training on 183555 raw words (91259 effective words) took 0.2s, 443386 effective words/s
# 2020-06-09 10:42:28,672 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:28,680 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:28,688 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:28,701 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:28,706 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:28,726 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:28,727 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:28,729 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:28,730 : INFO : EPOCH - 44 : training on 183555 raw words (91308 effective words) took 0.2s, 371713 effective words/s
# 2020-06-09 10:42:28,920 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:28,929 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:28,933 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:28,935 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:28,945 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:28,957 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:28,957 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:28,964 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:28,965 : INFO : EPOCH - 45 : training on 183555 raw words (91028 effective words) took 0.2s, 395103 effective words/s
# 2020-06-09 10:42:29,128 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:29,139 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:29,141 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:29,145 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:29,156 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:29,176 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:29,179 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:29,194 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:29,195 : INFO : EPOCH - 46 : training on 183555 raw words (91407 effective words) took 0.2s, 403631 effective words/s
# 2020-06-09 10:42:29,370 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:29,375 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:29,378 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:29,380 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:29,390 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:29,403 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:29,404 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:29,410 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:29,410 : INFO : EPOCH - 47 : training on 183555 raw words (91366 effective words) took 0.2s, 446515 effective words/s
# 2020-06-09 10:42:29,600 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:29,606 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:29,611 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:29,617 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:29,621 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:29,639 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:29,643 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:29,647 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:29,647 : INFO : EPOCH - 48 : training on 183555 raw words (91416 effective words) took 0.2s, 393085 effective words/s
# 2020-06-09 10:42:29,814 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:29,818 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:29,825 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:29,827 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:29,840 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:29,849 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:29,853 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:29,856 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:29,857 : INFO : EPOCH - 49 : training on 183555 raw words (91182 effective words) took 0.2s, 441395 effective words/s
# 2020-06-09 10:42:30,021 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:30,029 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:30,031 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:30,035 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:30,046 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:30,058 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:30,060 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:30,064 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:30,064 : INFO : EPOCH - 50 : training on 183555 raw words (91107 effective words) took 0.2s, 446728 effective words/s
# 2020-06-09 10:42:30,224 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:30,231 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:30,234 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:30,238 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:30,248 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:30,268 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:30,270 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:30,272 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:30,273 : INFO : EPOCH - 51 : training on 183555 raw words (91252 effective words) took 0.2s, 445646 effective words/s
# 2020-06-09 10:42:30,442 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:30,447 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:30,452 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:30,453 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:30,460 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:30,481 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:30,486 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:30,491 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:30,491 : INFO : EPOCH - 52 : training on 183555 raw words (91384 effective words) took 0.2s, 424753 effective words/s
# 2020-06-09 10:42:30,652 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:30,653 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:30,661 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:30,664 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:30,675 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:30,691 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:30,697 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:30,702 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:30,703 : INFO : EPOCH - 53 : training on 183555 raw words (91255 effective words) took 0.2s, 435751 effective words/s
# 2020-06-09 10:42:30,864 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:30,872 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:30,878 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:30,879 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:30,889 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:30,901 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:30,909 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:30,914 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:30,914 : INFO : EPOCH - 54 : training on 183555 raw words (91205 effective words) took 0.2s, 440414 effective words/s
# 2020-06-09 10:42:31,078 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:31,086 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:31,087 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:31,099 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:31,103 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:31,119 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:31,120 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:31,123 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:31,124 : INFO : EPOCH - 55 : training on 183555 raw words (91059 effective words) took 0.2s, 443031 effective words/s
# 2020-06-09 10:42:31,286 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:31,296 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:31,301 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:31,302 : INFO : worker thread finished; awaiting finish of 4 more threads
# ...
# 2020-06-09 10:42:45,334 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:45,338 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:45,339 : INFO : EPOCH - 122 : training on 183555 raw words (91115 effective words) took 0.2s, 455101 effective words/s
# 2020-06-09 10:42:45,498 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:45,505 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:45,506 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:45,513 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:45,519 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:45,529 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:45,536 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:45,542 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:45,543 : INFO : EPOCH - 123 : training on 183555 raw words (91277 effective words) took 0.2s, 455122 effective words/s
# 2020-06-09 10:42:45,703 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:45,712 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:45,716 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:45,718 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:45,731 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:45,742 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:45,744 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:45,750 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:45,751 : INFO : EPOCH - 124 : training on 183555 raw words (91346 effective words) took 0.2s, 447555 effective words/s
# 2020-06-09 10:42:45,909 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:45,918 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:45,921 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:45,922 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:45,934 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:45,944 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:45,946 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:45,950 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:45,951 : INFO : EPOCH - 125 : training on 183555 raw words (91108 effective words) took 0.2s, 462962 effective words/s
# 2020-06-09 10:42:46,109 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:46,121 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:46,123 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:46,126 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:46,134 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:46,147 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:46,148 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:46,154 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:46,154 : INFO : EPOCH - 126 : training on 183555 raw words (91333 effective words) took 0.2s, 456861 effective words/s
# 2020-06-09 10:42:46,318 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:46,321 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:46,325 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:46,333 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:46,340 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:46,354 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:46,356 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:46,360 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:46,361 : INFO : EPOCH - 127 : training on 183555 raw words (91169 effective words) took 0.2s, 449928 effective words/s
# 2020-06-09 10:42:46,518 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:46,521 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:46,530 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:46,531 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:46,539 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:46,551 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:46,554 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:46,556 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:46,557 : INFO : EPOCH - 128 : training on 183555 raw words (91070 effective words) took 0.2s, 472835 effective words/s
# 2020-06-09 10:42:46,720 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:46,730 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:46,732 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:46,737 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:46,747 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:46,761 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:46,763 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:46,767 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:46,768 : INFO : EPOCH - 129 : training on 183555 raw words (91503 effective words) took 0.2s, 442674 effective words/s
# 2020-06-09 10:42:46,936 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:46,941 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:46,950 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:46,954 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:46,960 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:46,973 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:46,975 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:46,984 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:46,985 : INFO : EPOCH - 130 : training on 183555 raw words (90891 effective words) took 0.2s, 425607 effective words/s
# 2020-06-09 10:42:47,147 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:47,155 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:47,163 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:47,175 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:47,191 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:47,195 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:47,214 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:47,217 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:47,218 : INFO : EPOCH - 131 : training on 183555 raw words (91021 effective words) took 0.2s, 396842 effective words/s
# 2020-06-09 10:42:47,364 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:47,368 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:47,393 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:47,394 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:47,418 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:47,424 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:47,435 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:47,438 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:47,438 : INFO : EPOCH - 132 : training on 183555 raw words (91471 effective words) took 0.2s, 420681 effective words/s
# 2020-06-09 10:42:47,617 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:47,618 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:47,621 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:47,625 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:47,633 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:47,652 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:47,654 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:47,661 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:47,661 : INFO : EPOCH - 133 : training on 183555 raw words (91457 effective words) took 0.2s, 416714 effective words/s
# 2020-06-09 10:42:47,827 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:47,831 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:47,837 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:47,844 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:47,848 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:47,862 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:47,865 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:47,871 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:47,872 : INFO : EPOCH - 134 : training on 183555 raw words (91285 effective words) took 0.2s, 440331 effective words/s
# 2020-06-09 10:42:48,023 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:48,032 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:48,037 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:48,038 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:48,048 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:48,064 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:48,066 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:48,068 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:48,069 : INFO : EPOCH - 135 : training on 183555 raw words (91327 effective words) took 0.2s, 471104 effective words/s
# 2020-06-09 10:42:48,231 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:48,232 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:48,238 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:48,248 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:48,259 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:48,265 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:48,269 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:48,274 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:48,275 : INFO : EPOCH - 136 : training on 183555 raw words (91400 effective words) took 0.2s, 450377 effective words/s
# 2020-06-09 10:42:48,432 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:48,440 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:48,442 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:48,450 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:48,454 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:48,468 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:48,474 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:48,480 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:48,480 : INFO : EPOCH - 137 : training on 183555 raw words (91058 effective words) took 0.2s, 448789 effective words/s
# 2020-06-09 10:42:48,634 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:48,642 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:48,647 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:48,648 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:48,659 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:48,671 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:48,672 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:48,679 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:48,679 : INFO : EPOCH - 138 : training on 183555 raw words (91256 effective words) took 0.2s, 468674 effective words/s
# 2020-06-09 10:42:48,836 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:48,842 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:48,847 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:48,850 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:48,859 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:48,871 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:48,873 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:48,882 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:48,882 : INFO : EPOCH - 139 : training on 183555 raw words (91365 effective words) took 0.2s, 456072 effective words/s
# 2020-06-09 10:42:49,033 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-09 10:42:49,041 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-09 10:42:49,050 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-09 10:42:49,053 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-09 10:42:49,061 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-09 10:42:49,076 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-09 10:42:49,076 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-09 10:42:49,078 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-09 10:42:49,078 : INFO : EPOCH - 140 : training on 183555 raw words (91148 effective words) took 0.2s, 473247 effective words/s
# 2020-06-09 10:42:49,079 : INFO : training on a 25697700 raw words (12780054 effective words) took 30.9s, 413608 effective words/s

# %% [markdown]
# ## Test similarity words

# %%
doc2vec_model.wv.most_similar("ai")
# Out:
# [('artificial_intelligence', 0.46956855058670044),
#  ('military', 0.43971365690231323),
#  ('application_ai', 0.4348776340484619),
#  ('use_ai', 0.4264654517173767),
#  ('deep_learning', 0.425575852394104),
#  ('pattern_recognition', 0.42197999358177185),
#  ('robot', 0.41511738300323486),
#  ('cybersecurity', 0.4029451906681061),
#  ('use_algorithm', 0.3911895155906677),
#  ('machine_learning', 0.38021665811538696)]

# %%
doc2vec_model.wv.most_similar("devops")
# Out:
# [('devops_team', 0.6376786828041077),
#  ('have_devops', 0.6120046377182007),
#  ('devops_philosophy', 0.5452255010604858),
#  ('philosophy', 0.5395946502685547),
#  ('continuous_integration', 0.51674884557724),
#  ('koombea_devops', 0.5150570869445801),
#  ('development_operation', 0.4901748299598694),
#  ('certify', 0.46187448501586914),
#  ('increase_quality', 0.41916316747665405),
#  ('simultaneously', 0.41699814796447754)]

# %%
doc2vec_model.wv.most_similar("python")
# Out:
# [('web_project', 0.775579571723938),
#  ('python_great', 0.6513786315917969),
#  ('python_web', 0.6238152384757996),
#  ('fabian', 0.538891613483429),
#  ('pro_con', 0.5154212117195129),
#  ('code_language', 0.4892086982727051),
#  ('pro', 0.4874246120452881),
#  ('efficient_way', 0.4825090765953064),
#  ('web_development', 0.4731321632862091),
#  ('pros', 0.46772879362106323)]

# %%
doc2vec_model.wv.most_similar("java")
# Out:
# [('object_orient', 0.695777952671051),
#  ('virtual_machine', 0.6950333118438721),
#  ('portability', 0.6027066111564636),
#  ('different_operating', 0.5992630124092102),
#  ('code_language', 0.5637282133102417),
#  ('active_community', 0.5116144418716431),
#  ('programming', 0.4552820324897766),
#  ('depend_need', 0.45088765025138855),
#  ('characterize', 0.4432867169380188),
#  ('banking_service', 0.42555302381515503)]

# %% [markdown]
# ## Visualize words embeddings

# %%
word_matrix = doc2vec_model.wv[doc2vec_model.wv.vocab]

# %% [markdown]
# ### Truncated svd to reduce dimension down to 50

# %%
from sklearn.decomposition import TruncatedSVD
truncated_svd = TruncatedSVD(n_components=50)

# %%
word_matrix_truncated = truncated_svd.fit_transform(word_matrix)

# %% [markdown]
# ### tsne manifold to reduce dimension down to 2

# %%
from sklearn.manifold import TSNE

# %%
matrix_ = TSNE(perplexity=50).fit_transform(word_matrix_truncated)

# %%
vocab = np.array(list(doc2vec_model.wv.vocab.keys()))

# %%
vocab[100:120]
# Out:
# array(['reveal', 'win', 'tie', 'code', 'intricate', 'create', 'will',
#        'able', 'hand', 'project', 'potential', 'high', 'roi', 'feedback',
#        'wise', 'app_development', 'comprehensive', 'scalability_testing',
#        'glitch', 'save'], dtype='<U25')

# %% [markdown]
# ### Visualize words

# %%
# %matplotlib inline
visualize_words_embedding(matrix_, vocab, total=300, width=15, height=10)

# %% [markdown]
# ## Visualize blogs embedding

# %%
blog_matrix = doc2vec_model.docvecs.vectors_docs

# %% [markdown]
# ### Trucated svd to reduce dimension down to 50

# %%
blog_matrix_truncated = TruncatedSVD(n_components=50).fit_transform(blog_matrix)

# %% [markdown]
# ### Tsne manifold to reduce dimension down to 2

# %%
blog_matrix_tsne = TSNE(n_components=2).fit_transform(blog_matrix_truncated)

# %% [markdown]
# ### Visualize blogs

# %%
from sklearn.cluster import KMeans

# %%
clusters = KMeans(n_clusters=25).fit_predict(blog_matrix_tsne)

# %%
import pickle

TFIDF_MATRIX = pickle.load(open("model/tfidf_bigrams.pickle", "rb"))
vocab_ = pickle.load(open("model/vocab_bigrams.pickle", "rb"))

# %%
# %matplotlib inline
plots_blogs_embedding(TFIDF_MATRIX, blog_matrix_tsne, vocab_, clusters, width=15, height=10)

# %% [markdown]
# # Similarity Query

# %%
from gensim.summarization import summarize

# %% [markdown]
# ## Pick a blog and summarize using gensim

# %%
print(blogs_df.title[455].upper())
print(summarize(blogs_df.normalize_data[455]))
# Out:
# 2020-06-09 10:50:30,722 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2020-06-09 10:50:30,723 : INFO : built Dictionary(329 unique tokens: ['bad', 'covid', 'depress', 'econom', 'enter']...) from 82 documents (total 573 corpus positions)
# 2020-06-09 10:50:30,724 : INFO : Building graph
# 2020-06-09 10:50:30,725 : INFO : Filling graph
# 2020-06-09 10:50:30,733 : INFO : Removing unreachable nodes of graph
# 2020-06-09 10:50:30,734 : INFO : Pagerank graph
# 2020-06-09 10:50:30,739 : INFO : Sorting pagerank scores
# FINTECH TRENDS 2020: THE GOOD, THE BAD, AND THE UGLY
# FinTech Trends 2020: The Good, the Bad, and the Ugly Due to the Covid-19 pandemic, the world is entering an economic turmoil not seen since the Great Depression.
# Governments all over the world are implementing generous aid programs to help companies and people, but uncertainty prevails.
# FinTech, a sector that was performing great before Covid-19, is at the crossroads between surviving the crisis and a universe of opportunities.
# In this post we analyze some of the most important FinTech trends that investors and managers should keep on their radar if they wish to stay afloat and come out of the crisis stronger.
# Although some FinTech companies are struggling due to the economy’s overall impact, it is safe to say that the majority continue to operate at levels of performance equal to or above before the pandemic.
# Some FinTech real estate and insurance companies seem to be having a hard time, although this seems more of a temporary issue rather than a new normal.
# Consumption in many non-essential industries has seen a major fall, affecting the circulation of money in the economy.
# With less money to buy certain goods and services, FinTech companies need to focus on delivering products that fall within households’ priorities.
# Countries and central banks are reducing their interest rates, affecting FinTech companies in one way or another.
# FinTech companies are not immune to shifts on the way we work as a result of the pandemic.
# FinTech has a great opportunity both in eCommerce customers as well as companies that need to grow to satisfy the increase in online demand.
# There seems to be a whole new market of companies that are seeking FinTech apps to help them adapt their businesses to the digital world.
# At Koombea we are excited to see what new FinTech apps will be developed in order to confront the crisis.
# One of the strongest trends we expect to see throughout 2020 and in the coming years is an increase in FinTech app development.
# Koombea has over 12 years of experience helping FinTech companies bring ideas to life.
# Contact us and make sure that your company stays afloat throughout this crisis.

# %%
import scipy

query = preprocess_data(blogs_df.normalize_data[455], regex, True, True)
query = bigrams[query]
query_embedding = doc2vec_model.infer_vector(query)

# Find the closest 3 sentences of the corpus for each query sentence based on cosine similarity
number_top_matches = 3 #@param {type: "number"}

print("Semantic Search Resutls")

distances = scipy.spatial.distance.cdist([query_embedding], blog_matrix, "cosine")[0]
results = zip(range(len(distances)), distances)
results = sorted(results, key=lambda x: x[1])
results = [(idx, 1-dis) for idx, dis in results]

values_ = [val[0] for val in results[1:]]
results[1:4]
# Out:
# Semantic Search Resutls
# [(447, 0.4891612508264118),
#  (408, 0.46049452575084693),
#  (430, 0.4550020829739755)]

# %%
print(blogs_df.title[values_[0]].upper())
print(summarize(blogs_df.normalize_data[values_[0]]))
print("\n")
print(blogs_df.title[values_[1]].upper())
print(summarize(blogs_df.normalize_data[values_[1]]))
print("\n")
print(blogs_df.title[values_[2]].upper())
print(summarize(blogs_df.normalize_data[values_[2]]))
# Out:
# 2020-06-09 11:10:16,254 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2020-06-09 11:10:16,256 : INFO : built Dictionary(321 unique tokens: ['financi', 'fintech', 'histor', 'institut', 'matter']...) from 85 documents (total 682 corpus positions)
# 2020-06-09 11:10:16,257 : INFO : Building graph
# 2020-06-09 11:10:16,257 : INFO : Filling graph
# 2020-06-09 11:10:16,274 : INFO : Removing unreachable nodes of graph
# 2020-06-09 11:10:16,275 : INFO : Pagerank graph
# 2020-06-09 11:10:16,284 : INFO : Sorting pagerank scores
# 2020-06-09 11:10:16,294 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2020-06-09 11:10:16,296 : INFO : built Dictionary(315 unique tokens: ['billion', 'compani', 'despit', 'econom', 'fintech']...) from 60 documents (total 554 corpus positions)
# 2020-06-09 11:10:16,297 : INFO : Building graph
# 2020-06-09 11:10:16,298 : INFO : Filling graph
# 2020-06-09 11:10:16,306 : INFO : Removing unreachable nodes of graph
# 2020-06-09 11:10:16,307 : INFO : Pagerank graph
# 2020-06-09 11:10:16,313 : INFO : Sorting pagerank scores
# 2020-06-09 11:10:16,324 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2020-06-09 11:10:16,326 : INFO : built Dictionary(267 unique tokens: ['crisi', 'current', 'fintech', 'get', 'learn']...) from 71 documents (total 503 corpus positions)
# 2020-06-09 11:10:16,327 : INFO : Building graph
# 2020-06-09 11:10:16,327 : INFO : Filling graph
# 2020-06-09 11:10:16,336 : INFO : Removing unreachable nodes of graph
# 2020-06-09 11:10:16,337 : INFO : Pagerank graph
# 2020-06-09 11:10:16,346 : INFO : Sorting pagerank scores
# FINTECH: WHO REGULATES IT AND WHY IT MATTERS
# Fintech: Who Regulates It and Why It Matters Financial institutions have historically been regulated.
# The result has been a strengthening of what is often referred to as Keynesian economics, in honor of John Maynard Keynes, the economist who established the modern basis for how governments need to intervene in the market for it to work properly.
# In the end, it doesn’t really matter if you agree or not with this, because, as Nobel laureate Milton Friedman stated, “We are all Keynesians now.”  Market regulation is a given in our globalized world, and as a result, the question is no longer if regulation is needed.
# Besides illegal activities, globalization has required countries to have a unified financial framework under which they can operate.
# This consensus is the result of important turning points throughout the 20th century that established how the international financial system works.
# What exists is mostly a series of international treaties and agreements between countries that establish the fundamentals of how the global financial system works.
# Understanding FinTech regulation at the national level poses a greater challenge because each country has its own approach.
# As a matter of fact, many countries do not even have a specific regulatory framework for FinTech.
# This results in many FinTech companies adopting the same regulations that apply to traditional financial institutions.
# For the case of the European Union, a series of multilateral institutions regulate financial activities, FinTech included.
# An important reason why many countries do not have FinTech regulations is because regulators usually cannot keep up with innovations.
# Why FinTech Regulation Matters for Your App
# In general, FinTech companies are faced with the challenge of meeting user demands, complying with regulations, and innovating.
# Building great apps that comply with financial regulations is not a responsibility you want to leave in the hands of just anyone.
# It is even better if your development partner can help you implement RegTech in your app; RegTech is a relatively new approach towards regulation that uses technology to maintain compliance.
# FinTech Regulation and App Development
# They need to make sure that their development partners understand the complex regulatory map.
#
#
# TOP FINTECH COMPANIES TO WATCH IN 2020
# For this reason, we would like to share with you examples of some of the companies that we consider are topping the charts through their innovative business models, user-centered experience, and well-crafted apps.
# It seeks to help its users by introducing responsible money management principles; it offers valuable educational content related to investing, retirement, and saving, to mention a few.
# As part of its business strategy, Acorns has partnered with some important brands in order to help its users manage their finances.
# Its partnership with PayPal has helped the company increase its users while consolidating itself as a major player in the new FinTech environment.
# In a world where finance is usually associated with predatory practices, Acorns stands out as what the new integral FinTech company can look like when users’ wellbeing is a priority.
# Opendoor has been part of this trend by developing a platform that helps its users simplify the process of buying and selling homes.
# Plaid has developed a set of developer-friendly APIs that allow the integration of various platforms in order to process information and deliver a great user experience.
# With its easy to use app and its innovative business model, it is revolutionizing the auto insurance industry by offering alternative pricing methods.
# The company offers various plans that help users achieve their financial goals by monitoring their performance.
# Stash helps users perform investments, manage their money as if it were an online bank, develop healthy financial habits, and learn about how the financial system works.
# FinTech companies that learn to use the power of IoT and develop great apps will surely have an advantage over their competitors.
# Let us help you build that great FinTech app.
#
#
# 8 USES OF AI AND MACHINE LEARNING IN FINTECH
# As more financial activities are done through apps, these two technologies are opening up great opportunities for a lot of people.
# FinTech companies large and small are using these technologies, paired up with powerful apps, for all sorts of purposes.
# FinTech apps are developing new and interesting ways in which users can process information.
# As a result, users can make use of complex information to improve their financial decision making.
# FinTech companies have taken notice of this and are implementing these solutions into apps so that users can take advantage of them.
# Because this industry is heavily driven by financial tools, FinTech apps are being used to determine risk levels.
# A combination of IoT technologies and FinTech app development has opened up for this industry the possibility to calculate a person’s risk level by assessing their driving skills through a mobile app.
# This is probably the most obvious way in which FinTech companies are benefiting from HiTech.
# FinTech companies that use these mechanisms need to make sure that they have everything worked out, otherwise, they risk segregating an important pool of users from their services.
# Apps have the power to help users perform robust calculations on important matters like their own personal finances at a very low cost and in a personalized way.
# Although this might seem obvious, it is an important way in which FinTech companies are using AI and ML.
# The combination of these technologies, together with powerful apps, has given companies and users the possibility to personalize finances.
# Artificial Intelligence and Machine Learning are two potent HiTech tools that the FinTech industry is using for everyone’s benefit.
# If you think your FinTech app can benefit from implementing Artificial Intelligence or Machine Learning, hit us up.
